# %% [markdown]
# # v7 - classical optimization followed by hardware execution (all at once)
#
# Now with negative times!
# ___________________
# ___________________
# ___________________

# %%
# %load_ext autoreload
# %autoreload 2

from troter_utils import *

# %% [markdown]
# ### Quantum Devices

# %%
# load IBMQ Account data
provider = IBMQ.load_account()

# Get backend for experiment
provider = IBMQ.get_provider(hub='ibm-q-community', group='ibmquantumawards', project='open-science-22')
jakarta = provider.get_backend('ibmq_jakarta')

# Simulated backend based on ibmq_jakarta's device noise profile
sim_noisy_jakarta = QasmSimulator.from_backend(provider.get_backend('ibmq_jakarta'))

# Noiseless simulated backend
sim_no_noise = QasmSimulator()

# %% [markdown]
# ____________

# %% [markdown]
# # IMPORTANT: classical optimization takes ~4h.
#
# # That's why the cells are frozen (unfreeze to run opt again - nbextensions is necessary!)
#
# # Skip to the "Hardware execution" section to submit jobs to hardware with best parameters read from file (previous classical optimization)
#
# Obs.: files were saved as parquet, because it allows for an easier parse of columns of lists (best_params, eg)

# %% [markdown]
# ____________

# %% [markdown]
# ## First order
#
# - Steps: 4 to 8;
# - Variable time;
# - Minimum time: 0.001 and 0.0005;

# %%
results = {"order" : [],
           "n_steps" : [],
           "t_min" : [],
           "state_tomo_fids" : [],
           "fid_pi" : [],
           "best_params" : []}

# %%
order = 1
uniform_times = False
backend_opt, backend_state_tomo = sim_noisy_jakarta, sim_noisy_jakarta
quadratic_loss = False

steps = range(4, 9)
min_times = [-np.pi]

combs = itertools.product(steps, min_times)

for trotter_steps, params_bounds_min in combs:
    
    print("\n\n")    
    print("#"*80)
    print("="*80)
    print("#"*80)
    print(f"Order: {order}".center(80))
    print(f"# steps: {trotter_steps}".center(80))
    print(f"min time: {params_bounds_min}".center(80))
    print("#"*80)
    print("="*80)
    print("#"*80)
    print("\n\n")
    
    fids, fidelity_pi, best_params = optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                                                             backend_opt, backend_state_tomo, quadratic_loss)
    
    results['order'].append(order)
    results['n_steps'].append(trotter_steps)
    results['t_min'].append(params_bounds_min)
    results['state_tomo_fids'].append(fids)
    results['fid_pi'].append(fidelity_pi)
    results['best_params'].append(best_params)
# Out:
# ################################################################################
# ================================================================================
# ################################################################################
#                                     Order: 1
#                                    # steps: 4
#                           min time: -3.141592653589793
# ################################################################################
# ================================================================================
# ################################################################################
# ################################################################################
#
# Starting optimization!
#
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.1
# ==================================================
#
# Iter 1 done!
# Loss value: -0.24475
# Current parameters: [-1.251  2.136  1.029  1.227] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.06332
# Current parameters: [-0.589  1.542  1.503  0.686] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.23426
# Current parameters: [-0.452  1.569  1.511  0.514] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.08568
# Current parameters: [ 1.004  1.579  1.479 -0.92 ] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.61264
# Current parameters: [-0.072  1.576  1.622  0.015] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.61431
# Current parameters: [-4.296e-02  1.580e+00  1.603e+00  9.696e-04] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.61507
# Current parameters: [-0.005  1.583  1.575 -0.012] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.6151
# Current parameters: [-0.005  1.581  1.574 -0.008] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.61512
# Current parameters: [-5.297e-03  1.576e+00  1.570e+00  2.043e-04] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.61512
# Current parameters: [-0.002  1.575  1.567  0.002] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.61512
#             Iterations: 10
#             Function evaluations: 64
#             Gradient evaluations: 10
#
# Total time of optimization: 00:00:57
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.01
# ==================================================
#
# Iter 1 done!
# Loss value: -0.22848
# Current parameters: [-1.13   2.002  1.041  1.228] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.09025
# Current parameters: [-0.498  1.344  1.624  0.673] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.28363
# Current parameters: [-0.313  1.317  1.623  0.514] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.47655
# Current parameters: [ 1.379  1.614  1.369 -1.22 ] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.61432
# Current parameters: [ 0.023  1.512  1.617 -0.01 ] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.61463
# Current parameters: [ 0.02   1.527  1.608 -0.014] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.6149
# Current parameters: [ 0.014  1.539  1.601 -0.013] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.61506
# Current parameters: [-0.007  1.59   1.566 -0.007] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.61512
# Current parameters: [-0.004  1.576  1.574 -0.005] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.61512
# Current parameters: [ 8.306e-04  1.566e+00  1.579e+00 -4.296e-03] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.61512
#             Iterations: 10
#             Function evaluations: 65
#             Gradient evaluations: 10
#
# Total time of optimization: 00:00:57
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.001
# ==================================================
#
# Iter 1 done!
# Loss value: -0.23832
# Current parameters: [-1.113  1.977  1.063  1.215] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.26594
# Current parameters: [-0.524  1.634  1.592  0.44 ] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.51139
# Current parameters: [-0.225  1.468  1.598  0.3  ] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.54114
# Current parameters: [0.215 1.331 1.458 0.137] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.60924
# Current parameters: [0.014 1.476 1.548 0.104] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.61327
# Current parameters: [0.029 1.499 1.557 0.056] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.61429
# Current parameters: [0.032 1.525 1.549 0.036] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.61496
# Current parameters: [0.022 1.561 1.555 0.003] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.61503
# Current parameters: [0.017 1.564 1.557 0.003] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.61372
# Current parameters: [-0.064  1.617  1.602 -0.013] (sum to 3.14)
#
# Iter 11 done!
# Loss value: -0.61512
# Current parameters: [-3.304e-04  1.576e+00  1.567e+00 -8.119e-04] (sum to 3.14)
#
# Iter 12 done!
# Loss value: -0.61512
# Current parameters: [-3.304e-04  1.576e+00  1.567e+00 -8.119e-04] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.61512
#             Iterations: 12
#             Function evaluations: 63
#             Gradient evaluations: 12
#
# Total time of optimization: 00:01:01
# Optimization results:
#   optimizer    eps                                       final_params  \
# 0     slsqp  0.100  [-0.0052939301769448855, 1.576439440713225, 1....
# 1     slsqp  0.010  [-0.0037136755427489804, 1.5758562018612403, 1...
# 2     slsqp  0.001  [-0.00033040611771276845, 1.5755405883185396, ...
#
#    final_loss
# 0    -0.61512
# 1    -0.61512
# 2    -0.61512
# Best parameters (sum to 3.14):	[-5.294e-03  1.576e+00  1.570e+00  2.057e-04]
# Best parameters (sum to 1):	[-1.685e-03  5.018e-01  4.998e-01  6.549e-05]
# ################################################################################
# Single trotterization step:
# ################################################################################
#
# All steps + measurements of state tomography:
# ################################################################################
#
# 1/8 - Job ID 0cc7e529-9e12-4026-a5f5-ac152b1dbbb7
# 2/8 - Job ID 0746a66d-df0d-4935-a500-72d3e82b7cde
# 3/8 - Job ID 5887604a-b150-430d-afe6-5e7bbe692512
# 4/8 - Job ID dd50365f-fae7-49b1-80ff-6069d1e20583
# 5/8 - Job ID c044f699-5b47-435c-b2e7-70d42050bd95
# 6/8 - Job ID 3f2153d7-ecef-41e3-94ba-a6f0471b48c5
# 7/8 - Job ID 73db0fb3-82fa-47c2-ab7c-daef77cccab2
# 8/8 - Job ID 1d8e0fb7-50a0-4960-b7aa-378eaa6ed9dd
#
# ################################################################################
#
# Final results - order: 1 - strotter steps: 4
#
# State tomography fidelity = 0.6149 ± 0.0016
#
# ################################################################################
#
# Starting simulation for times from 0 to pi!
# Simulation ended!
# Total time of simulation: 00:01:18
# ################################################################################
# ================================================================================
# ################################################################################
#                                     Order: 1
#                                    # steps: 5
#                           min time: -3.141592653589793
# ################################################################################
# ================================================================================
# ################################################################################
# ################################################################################
#
# Starting optimization!
#
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.1
# ==================================================
#
# Iter 1 done!
# Loss value: -0.04017
# Current parameters: [-0.23   3.005  1.791  0.802 -2.226] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.09181
# Current parameters: [-0.34   2.928  1.872  0.967 -2.286] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.1167
# Current parameters: [-0.767  2.341  2.425  1.998 -2.855] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.28243
# Current parameters: [-0.44   2.636  1.922  1.623 -2.6  ] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.15503
# Current parameters: [ 0.091  2.128  0.954  3.11  -3.142] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.39473
# Current parameters: [-0.227  2.703  1.745  1.749 -2.828] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.57512
# Current parameters: [-0.114  2.973  1.739  1.685 -3.142] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.59129
# Current parameters: [-0.075  2.992  1.731  1.636 -3.142] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.61354
# Current parameters: [ 0.01   3.077  1.648  1.548 -3.142] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.66938
# Current parameters: [ 0.053  3.142  1.582  1.507 -3.142] (sum to 3.14)
#
# Iter 11 done!
# Loss value: -0.56308
# Current parameters: [ 0.037  3.142  1.581  1.524 -3.142] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.66938
#             Iterations: 11
#             Function evaluations: 80
#             Gradient evaluations: 11
#
# Total time of optimization: 00:01:06
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.01
# ==================================================
#
# Iter 1 done!
# Loss value: -0.05634
# Current parameters: [-0.186  2.951  1.708  0.918 -2.251] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.10027
# Current parameters: [-0.274  2.843  1.724  1.154 -2.306] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.12633
# Current parameters: [-0.255  2.779  1.816  1.232 -2.43 ] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.12682
# Current parameters: [-0.3    2.419  2.338  1.827 -3.142] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.36082
# Current parameters: [-0.146  2.637  1.917  1.659 -2.925] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.38593
# Current parameters: [ 0.161  3.142  1.123  1.858 -3.142] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.57184
# Current parameters: [ 0.156  3.142  1.317  1.655 -3.128] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.53447
# Current parameters: [-0.088  3.142  1.495  1.515 -2.921] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.61313
# Current parameters: [ 0.017  3.142  1.486  1.638 -3.142] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.56298
# Current parameters: [ 0.003  3.131  1.515  1.633 -3.142] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.61313
#             Iterations: 10
#             Function evaluations: 75
#             Gradient evaluations: 10
#
# Total time of optimization: 00:01:02
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.001
# ==================================================
#
# Iter 1 done!
# Loss value: -0.05999
# Current parameters: [-0.186  2.954  1.71   0.932 -2.269] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.10173
# Current parameters: [-0.237  2.879  1.713  1.126 -2.34 ] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.16447
# Current parameters: [-0.208  2.857  1.75   1.267 -2.524] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.47678
# Current parameters: [-0.094  2.835  1.65   1.892 -3.142] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.61506
# Current parameters: [ 0.011  3.142  1.559  1.571 -3.142] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.56425
# Current parameters: [ 0.007  3.138  1.563  1.575 -3.142] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.56388
# Current parameters: [-0.012  3.126  1.577  1.593 -3.142] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.54941
# Current parameters: [-0.106  3.061  1.646  1.681 -3.142] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.21001
# Current parameters: [-0.575  2.74   1.995  2.123 -3.142] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.56425
# Current parameters: [ 0.006  3.139  1.564  1.574 -3.142] (sum to 3.14)
#
# Iter 11 done!
# Loss value: -0.56418
# Current parameters: [ 0.014  3.142  1.562  1.566 -3.142] (sum to 3.14)
#
# Iter 12 done!
# Loss value: -0.56364
# Current parameters: [ 0.031  3.142  1.559  1.551 -3.142] (sum to 3.14)
#
# Iter 13 done!
# Loss value: -0.66515
# Current parameters: [ 0.103  3.142  1.548  1.49  -3.142] (sum to 3.14)
#
# Iter 14 done!
# Loss value: -0.56322
# Current parameters: [ 0.043  3.142  1.548  1.55  -3.142] (sum to 3.14)
#
# Iter 15 done!
# Loss value: -0.62324
# Current parameters: [-0.197  3.142  1.548  1.79  -3.142] (sum to 3.14)
#
# Iter 16 done!
# Loss value: -0.67132
# Current parameters: [ 0.015  3.142  1.556  1.57  -3.142] (sum to 3.14)
#
# Iter 17 done!
# Loss value: -0.67132
# Current parameters: [ 0.015  3.142  1.556  1.57  -3.142] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.67132
#             Iterations: 18
#             Function evaluations: 175
#             Gradient evaluations: 17
#
# Total time of optimization: 00:02:22
# Optimization results:
#   optimizer    eps                                       final_params  \
# 2     slsqp  0.001  [0.01479146504227919, 3.141592653589793, 1.556...
# 0     slsqp  0.100  [0.052679188224340145, 3.1415926535895236, 1.5...
# 1     slsqp  0.010  [0.017262403273262023, 3.1415926371144067, 1.4...
#
#    final_loss
# 2    -0.67132
# 0    -0.66938
# 1    -0.61313
# Best parameters (sum to 3.14):	[ 0.015  3.142  1.556  1.57  -3.142]
# Best parameters (sum to 1):	[ 0.005  1.     0.495  0.5   -1.   ]
# ################################################################################
# Single trotterization step:
# ################################################################################
#
# All steps + measurements of state tomography:
# ################################################################################
#
# 1/8 - Job ID de81beff-895c-4ee8-b549-705f3e35c917
# 2/8 - Job ID 17479fc4-76c6-4341-bc6f-0647eee06159
# 3/8 - Job ID 8f97e934-668a-44f8-aea6-2dc2cd320d8e
# 4/8 - Job ID 09542ad2-e326-46a5-961a-036e052af139
# 5/8 - Job ID a1d93aa8-8817-43d2-8aff-9565bdcaae8d
# 6/8 - Job ID 306b2409-f07e-4b09-85b7-6dd28675dbe9
# 7/8 - Job ID c9dd5708-e592-4046-8282-f613c9022120
# 8/8 - Job ID 32b028e9-7649-4974-851b-9302f842b891
#
# ################################################################################
#
# Final results - order: 1 - strotter steps: 5
#
# State tomography fidelity = 0.6719 ± 0.0018
#
# ################################################################################
#
# Starting simulation for times from 0 to pi!
# Simulation ended!
# Total time of simulation: 00:01:51
# ################################################################################
# ================================================================================
# ################################################################################
#                                     Order: 1
#                                    # steps: 6
#                           min time: -3.141592653589793
# ################################################################################
# ================================================================================
# ################################################################################
# ################################################################################
#
# Starting optimization!
#
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.1
# ==================================================
#
# Iter 1 done!
# Loss value: -0.3374
# Current parameters: [-0.17   3.142  1.935  1.232 -1.536 -1.461] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.54945
# Current parameters: [-0.089  3.142  1.558  1.498 -1.517 -1.45 ] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.56356
# Current parameters: [-0.004  3.142  1.597  1.513 -1.544 -1.561] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.56388
# Current parameters: [-0.003  3.142  1.596  1.524 -1.549 -1.567] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.56422
# Current parameters: [-0.005  3.142  1.586  1.557 -1.56  -1.578] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.56424
# Current parameters: [-0.004  3.142  1.581  1.564 -1.565 -1.577] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.56428
# Current parameters: [-2.303e-03  3.142e+00  1.576e+00  1.568e+00 -1.568e+00 -1.573e+00] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.56428
# Current parameters: [ 1.273e-03  3.142e+00  1.570e+00  1.573e+00 -1.574e+00 -1.570e+00] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.56428
#             Iterations: 8
#             Function evaluations: 67
#             Gradient evaluations: 8
#
# Total time of optimization: 00:00:58
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.01
# ==================================================
#
# Iter 1 done!
# Loss value: -0.1477
# Current parameters: [-0.246  3.142  2.027  1.103 -1.443 -1.442] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.51801
# Current parameters: [-0.154  3.142  1.58   1.418 -1.429 -1.415] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.55633
# Current parameters: [ 0.114  3.142  1.493  1.608 -1.562 -1.653] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.56389
# Current parameters: [ 0.026  3.142  1.535  1.58  -1.55  -1.592] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.56412
# Current parameters: [ 0.013  3.142  1.544  1.58  -1.553 -1.584] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.56423
# Current parameters: [-2.138e-05  3.142e+00  1.558e+00  1.575e+00 -1.567e+00 -1.567e+00] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.56427
# Current parameters: [-3.932e-04  3.142e+00  1.563e+00  1.576e+00 -1.572e+00 -1.567e+00] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.56428
# Current parameters: [ 1.794e-04  3.142e+00  1.566e+00  1.576e+00 -1.572e+00 -1.569e+00] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.56428
# Current parameters: [ 4.459e-04  3.142e+00  1.568e+00  1.574e+00 -1.573e+00 -1.569e+00] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.56428
#             Iterations: 9
#             Function evaluations: 74
#             Gradient evaluations: 9
#
# Total time of optimization: 00:01:10
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.001
# ==================================================
#
# Iter 1 done!
# Loss value: -0.11302
# Current parameters: [-0.288  3.142  2.038  1.051 -1.391 -1.411] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.38356
# Current parameters: [-0.264  3.142  1.704  1.26  -1.383 -1.316] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.05022
# Current parameters: [ 0.702  3.142 -1.698  3.142 -1.315 -0.831] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.49478
# Current parameters: [-0.161  3.142  1.492  1.449 -1.445 -1.334] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.35201
# Current parameters: [-0.171  3.142  1.827  1.868 -1.688 -1.836] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.55823
# Current parameters: [-0.063  3.142  1.587  1.503 -1.527 -1.499] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.51915
# Current parameters: [-0.021  3.142  1.604  1.513 -1.549 -1.547] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.29227
# Current parameters: [ 0.313  3.142  1.885  1.73  -1.942 -1.985] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.14238
# Current parameters: [ 1.285  3.142  2.597  2.26  -3.001 -3.142] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.51923
# Current parameters: [-0.029  3.142  1.591  1.535 -1.548 -1.549] (sum to 3.14)
#
# Iter 11 done!
# Loss value: -0.56245
# Current parameters: [-0.005  3.142  1.56   1.53  -1.576 -1.51 ] (sum to 3.14)
#
# Iter 12 done!
# Loss value: -0.56257
# Current parameters: [-1.437e-03  3.142e+00  1.557e+00  1.534e+00 -1.579e+00 -1.510e+00] (sum to 3.14)
#
# Iter 13 done!
# Loss value: -0.56308
# Current parameters: [ 0.018  3.142  1.537  1.562 -1.601 -1.516] (sum to 3.14)
#
# Iter 14 done!
# Loss value: -0.51855
# Current parameters: [ 0.13   3.142  1.408  1.754 -1.731 -1.561] (sum to 3.14)
#
# Iter 15 done!
# Loss value: -0.51892
# Current parameters: [ 0.022  3.142  1.533  1.569 -1.605 -1.519] (sum to 3.14)
#
# Iter 16 done!
# Loss value: -0.56321
# Current parameters: [ 0.017  3.142  1.539  1.565 -1.6   -1.52 ] (sum to 3.14)
#
# Iter 17 done!
# Loss value: -0.5585
# Current parameters: [-0.076  3.142  1.64   1.481 -1.506 -1.539] (sum to 3.14)
#
# Iter 18 done!
# Loss value: -0.56332
# Current parameters: [ 0.006  3.142  1.552  1.554 -1.589 -1.523] (sum to 3.14)
#
# Iter 19 done!
# Loss value: -0.40021
# Current parameters: [ 0.242  3.142  1.355  1.743 -1.811 -1.529] (sum to 3.14)
#
# Iter 20 done!
# Loss value: -0.56333
# Current parameters: [ 0.007  3.142  1.551  1.555 -1.59  -1.524] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.56333
#             Iterations: 20
#             Function evaluations: 174
#             Gradient evaluations: 20
#
# Total time of optimization: 00:02:30
# Optimization results:
#   optimizer    eps                                       final_params  \
# 0     slsqp  0.100  [-0.0022995687072801868, 3.141592653589793, 1....
# 1     slsqp  0.010  [0.0001796319127924832, 3.141592653589793, 1.5...
# 2     slsqp  0.001  [0.007947812545326748, 3.1415926535896026, 1.5...
#
#    final_loss
# 0    -0.56428
# 1    -0.56428
# 2    -0.56333
# Best parameters (sum to 3.14):	[-2.300e-03  3.142e+00  1.576e+00  1.568e+00 -1.568e+00 -1.573e+00]
# Best parameters (sum to 1):	[-7.320e-04  1.000e+00  5.017e-01  4.990e-01 -4.993e-01 -5.007e-01]
# ################################################################################
# Single trotterization step:
# ################################################################################
#
# All steps + measurements of state tomography:
# ################################################################################
#
# 1/8 - Job ID 896aaa28-024e-426e-b5d2-1faf601bc7b4
# 2/8 - Job ID 984f2ffe-8c45-4f82-bcce-3cb42d76c7d1
# 3/8 - Job ID cbdbc8f7-f519-4aa8-bc86-524bbd3db0cd
# 4/8 - Job ID 0c92ba12-0d00-4728-a36e-0df45871f1c2
# 5/8 - Job ID f1c020fe-93a1-4fa2-832a-56b902f8b8cc
# 6/8 - Job ID cf2f23a0-ec3a-4c99-9adb-61c271605348
# 7/8 - Job ID 745ebae1-4e38-427a-b326-fc2f31d71373
# 8/8 - Job ID 92a6644d-dd4a-4a78-b67a-18cd00ec38f4
#
# ################################################################################
#
# Final results - order: 1 - strotter steps: 6
#
# State tomography fidelity = 0.5641 ± 0.0012
#
# ################################################################################
#
# Starting simulation for times from 0 to pi!
# Simulation ended!
# Total time of simulation: 00:01:37
# ################################################################################
# ================================================================================
# ################################################################################
#                                     Order: 1
#                                    # steps: 7
#                           min time: -3.141592653589793
# ################################################################################
# ================================================================================
# ################################################################################
# ################################################################################
#
# Starting optimization!
#
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.1
# ==================================================
#
# Iter 1 done!
# Loss value: -0.08571
# Current parameters: [ 0.251  3.142  2.302  1.585 -1.23  -0.965 -1.943] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.17581
# Current parameters: [ 0.466  2.937  2.269  1.67  -1.098 -1.156 -1.946] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.11253
# Current parameters: [ 3.142  0.379  2.034  3.019 -0.353 -2.726 -2.353] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.28494
# Current parameters: [ 1.103  2.533  2.095  2.094 -0.811 -1.555 -2.317] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.31851
# Current parameters: [ 0.595  2.747  2.329  2.029 -0.963 -1.409 -2.187] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.43875
# Current parameters: [ 0.793  2.514  2.287  2.145 -0.854 -1.48  -2.264] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.43001
# Current parameters: [ 0.622  2.308  2.53   2.531 -0.706 -1.618 -2.525] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.46603
# Current parameters: [ 0.739  2.412  2.428  2.315 -0.802 -1.575 -2.376] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.46564
# Current parameters: [ 0.737  2.422  2.407  2.301 -0.807 -1.563 -2.355] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.46696
#             Iterations: 9
#             Function evaluations: 89
#             Gradient evaluations: 9
#
# Total time of optimization: 00:01:40
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.01
# ==================================================
#
# Iter 1 done!
# Loss value: -0.09229
# Current parameters: [ 0.188  3.142  2.345  1.605 -1.192 -1.08  -1.867] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.1047
# Current parameters: [ 0.186  3.142  2.3    1.674 -1.105 -1.162 -1.894] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.11969
# Current parameters: [ 0.196  3.142  2.301  1.782 -1.112 -1.217 -1.95 ] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.14383
# Current parameters: [ 0.39   3.142  2.326  3.003 -1.391 -1.857 -2.471] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.15397
# Current parameters: [ 0.572  3.142  2.239  3.127 -1.493 -2.044 -2.402] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.09014
# Current parameters: [ 0.616  3.142  2.074  2.255 -1.492 -1.673 -1.779] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.29593
# Current parameters: [ 0.534  3.142  1.988  2.813 -1.664 -1.735 -1.936] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.44243
# Current parameters: [ 0.19   3.142  1.825  3.142 -1.909 -1.659 -1.588] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.51951
# Current parameters: [-8.246e-04  3.142e+00  1.613e+00  3.142e+00 -1.620e+00 -1.549e+00
#  -1.584e+00] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.47935
# Current parameters: [-0.01   3.14   1.597  3.142 -1.609 -1.546 -1.573] (sum to 3.14)
#
# Iter 11 done!
# Loss value: -0.4747
# Current parameters: [-0.045  3.134  1.534  3.142 -1.565 -1.53  -1.529] (sum to 3.14)
#
# Iter 12 done!
# Loss value: -0.12061
# Current parameters: [-1.402  2.877 -0.562  3.142  0.338 -0.924 -0.326] (sum to 3.14)
#
# Iter 13 done!
# Loss value: -0.47942
# Current parameters: [-0.008  3.14   1.594  3.142 -1.606 -1.547 -1.574] (sum to 3.14)
#
# Iter 14 done!
# Loss value: -0.47894
# Current parameters: [ 0.007  3.142  1.605  3.142 -1.607 -1.559 -1.588] (sum to 3.14)
#
# Iter 15 done!
# Loss value: -0.56367
# Current parameters: [ 0.014  3.142  1.598  3.142 -1.605 -1.564 -1.583] (sum to 3.14)
#
# Iter 16 done!
# Loss value: -0.564
# Current parameters: [ 0.008  3.142  1.588  3.142 -1.593 -1.562 -1.582] (sum to 3.14)
#
# Iter 17 done!
# Loss value: -0.47954
# Current parameters: [-0.007  3.142  1.558  3.142 -1.559 -1.556 -1.577] (sum to 3.14)
#
# Iter 18 done!
# Loss value: -0.46117
# Current parameters: [-0.065  3.142  1.436  3.142 -1.422 -1.531 -1.56 ] (sum to 3.14)
#
# Iter 19 done!
# Loss value: -0.10037
# Current parameters: [-0.359  3.142  0.828  3.142 -0.731 -1.408 -1.471] (sum to 3.14)
#
# Iter 20 done!
# Loss value: -0.56423
# Current parameters: [-1.319e-03  3.142e+00  1.568e+00  3.142e+00 -1.571e+00 -1.559e+00
#  -1.579e+00] (sum to 3.14)
#
# Iter 21 done!
# Loss value: -0.56424
# Current parameters: [-7.670e-04  3.142e+00  1.571e+00  3.142e+00 -1.571e+00 -1.562e+00
#  -1.579e+00] (sum to 3.14)
#
# Iter 22 done!
# Loss value: -0.56424
# Current parameters: [-1.484e-03  3.142e+00  1.569e+00  3.142e+00 -1.571e+00 -1.560e+00
#  -1.579e+00] (sum to 3.14)
#
# Iter 23 done!
# Loss value: -0.56422
# Current parameters: [-0.005  3.142  1.564  3.142 -1.565 -1.559 -1.577] (sum to 3.14)
#
# Iter 24 done!
# Loss value: -0.56347
# Current parameters: [-0.017  3.142  1.541  3.142 -1.543 -1.552 -1.571] (sum to 3.14)
#
# Iter 25 done!
# Loss value: -0.54569
# Current parameters: [-0.078  3.142  1.427  3.142 -1.433 -1.518 -1.54 ] (sum to 3.14)
#
# Iter 26 done!
# Loss value: -0.1165
# Current parameters: [-0.382  3.142  0.855  3.142 -0.884 -1.348 -1.382] (sum to 3.14)
#
# Iter 27 done!
# Loss value: -0.09221
# Current parameters: [-1.905  3.142 -2.002  3.142  1.861 -0.499 -0.597] (sum to 3.14)
#
# Iter 28 done!
# Loss value: -0.26277
# Current parameters: [-2.513  3.142 -3.142  3.142  2.957 -0.161 -0.283] (sum to 3.14)
#
# Iter 29 done!
# Loss value: -0.24235
# Current parameters: [-2.513  3.142 -3.142  3.142  2.958 -0.162 -0.283] (sum to 3.14)
#
# Iter 30 done!
# Loss value: -0.31545
# Current parameters: [-2.514  3.142 -3.142  3.142  2.959 -0.163 -0.282] (sum to 3.14)
#
# Iter 31 done!
# Loss value: -0.26376
# Current parameters: [-2.515  3.142 -3.142  3.142  2.96  -0.163 -0.282] (sum to 3.14)
#
# Iter 32 done!
# Loss value: -0.26403
# Current parameters: [-2.516  3.142 -3.142  3.142  2.961 -0.164 -0.281] (sum to 3.14)
#
# Iter 33 done!
# Loss value: -0.28925
# Current parameters: [-2.517  3.142 -3.142  3.142  2.963 -0.165 -0.281] (sum to 3.14)
#
# Iter 34 done!
# Loss value: -0.26609
# Current parameters: [-2.521  3.142 -3.142  3.142  2.968 -0.168 -0.279] (sum to 3.14)
#
# Iter 35 done!
# Loss value: -0.25038
# Current parameters: [-2.537  3.142 -3.142  3.142  2.99  -0.182 -0.27 ] (sum to 3.14)
#
# Iter 36 done!
# Loss value: -0.3605
# Current parameters: [-2.615  3.142 -3.142  3.142  3.095 -0.25  -0.23 ] (sum to 3.14)
#
# Iter 37 done!
# Loss value: -0.27591
# Current parameters: [-2.655  3.142 -3.112  3.142  3.142 -0.308 -0.209] (sum to 3.14)
#
# Iter 38 done!
# Loss value: -0.07026
# Current parameters: [-2.806  3.142 -2.269  3.142  3.142 -1.081 -0.128] (sum to 3.14)
#
# Iter 39 done!
# Loss value: -0.33199
# Current parameters: [-3.142  3.142 -0.386  3.142  3.142 -2.807  0.051] (sum to 3.14)
#
# Iter 40 done!
# Loss value: -0.56163
# Current parameters: [-3.142  3.142  0.051  3.142  3.037 -3.142  0.053] (sum to 3.14)
#
# Iter 41 done!
# Loss value: -0.51702
# Current parameters: [-3.142  3.142  0.049  3.142  3.039 -3.142  0.054] (sum to 3.14)
#
# Iter 42 done!
# Loss value: -0.61203
# Current parameters: [-3.142  3.142  0.047  3.142  3.04  -3.142  0.055] (sum to 3.14)
#
# Iter 43 done!
# Loss value: -0.67066
# Current parameters: [-3.142  3.142  0.039  3.142  3.088 -3.142  0.015] (sum to 3.14)
#
# Iter 44 done!
# Loss value: -0.67109
# Current parameters: [-3.142  3.142  0.025  3.142  3.105 -3.142  0.011] (sum to 3.14)
#
# Iter 45 done!
# Loss value: -0.73621
# Current parameters: [-3.142  3.142 -0.007  3.142  3.142 -3.142  0.007] (sum to 3.14)
#
# Iter 46 done!
# Loss value: -0.67134
# Current parameters: [-3.142  3.142 -0.009  3.142  3.142 -3.142  0.006] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.73621
#             Iterations: 47
#             Function evaluations: 628
#             Gradient evaluations: 46
#
# Total time of optimization: 00:09:34
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.001
# ==================================================
#
# Iter 1 done!
# Loss value: -0.09211
# Current parameters: [ 0.17   3.142  2.346  1.598 -1.193 -1.093 -1.828] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.10412
# Current parameters: [ 0.079  3.142  2.274  1.706 -1.095 -1.113 -1.85 ] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.14489
# Current parameters: [-0.051  3.142  2.332  1.843 -1.063 -1.214 -1.847] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.2597
# Current parameters: [-1.488  3.142  3.142  3.142 -0.982 -2.053 -1.76 ] (sum to 3.14)
# Iter 5 done!
# Loss value: -0.27005
# Current parameters: [-1.143  3.142  3.142  3.142 -1.283 -1.8   -2.057] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.47624
# Current parameters: [-1.446  3.142  3.142  3.142 -1.26  -1.699 -1.879] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.10116
# Current parameters: [-2.936  3.142  3.142  3.142 -3.085  0.524 -0.786] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.47112
# Current parameters: [-1.599  3.142  3.142  3.142 -1.517 -1.46  -1.708] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.61076
# Current parameters: [-1.463  3.142  3.142  3.142 -1.633 -1.615 -1.572] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.61359
# Current parameters: [-1.501  3.142  3.142  3.142 -1.626 -1.583 -1.573] (sum to 3.14)
#
# Iter 11 done!
# Loss value: -0.47903
# Current parameters: [-1.543  3.142  3.142  3.142 -1.611 -1.551 -1.578] (sum to 3.14)
#
# Iter 12 done!
# Loss value: -0.4609
# Current parameters: [-1.71   3.142  3.142  3.142 -1.554 -1.423 -1.595] (sum to 3.14)
#
# Iter 13 done!
# Loss value: -0.06388
# Current parameters: [-2.542  3.142  3.142  3.142 -1.273 -0.785 -1.683] (sum to 3.14)
#
# Iter 14 done!
# Loss value: -0.30884
# Current parameters: [-3.142  3.142  3.142  3.142 -1.069 -0.324 -1.747] (sum to 3.14)
#
# Iter 15 done!
# Loss value: -0.30836
# Current parameters: [-3.142  3.142  3.142  3.142 -1.068 -0.324 -1.747] (sum to 3.14)
#
# Iter 16 done!
# Loss value: -0.36192
# Current parameters: [-3.141  3.142  3.142  3.142 -1.07  -0.325 -1.748] (sum to 3.14)
#
# Iter 17 done!
# Loss value: -0.61431
# Current parameters: [-1.607  3.142  3.142  3.142 -1.56  -1.52  -1.596] (sum to 3.14)
#
# Iter 18 done!
# Loss value: -0.61495
# Current parameters: [-1.57   3.142  3.142  3.142 -1.591 -1.537 -1.586] (sum to 3.14)
#
# Iter 19 done!
# Loss value: -0.61495
# Current parameters: [-1.57   3.142  3.142  3.142 -1.591 -1.537 -1.586] (sum to 3.14)
#
# Iter 20 done!
# Loss value: -0.47955
# Current parameters: [-1.571  3.142  3.142  3.142 -1.591 -1.537 -1.585] (sum to 3.14)
#
# Iter 21 done!
# Loss value: -0.61495
# Current parameters: [-1.571  3.142  3.142  3.142 -1.591 -1.537 -1.585] (sum to 3.14)
#
# Iter 22 done!
# Loss value: -0.61495
# Current parameters: [-1.571  3.142  3.142  3.142 -1.591 -1.537 -1.585] (sum to 3.14)
#
# Iter 23 done!
# Loss value: -0.61495
# Current parameters: [-1.571  3.142  3.142  3.142 -1.591 -1.537 -1.585] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.61495
#             Iterations: 26
#             Function evaluations: 273
#             Gradient evaluations: 23
#
# Total time of optimization: 00:04:22
# Optimization results:
#   optimizer    eps                                       final_params  \
# 1     slsqp  0.010  [-3.1415926535897927, 3.141592653589793, -0.00...
# 2     slsqp  0.001  [-1.570587116881619, 3.141592653589793, 3.1415...
# 0     slsqp  0.100  [0.7286781347082124, 2.4164234288439057, 2.413...
#
#    final_loss
# 1    -0.73621
# 2    -0.61495
# 0    -0.46696
# Best parameters (sum to 3.14):	[-3.142  3.142 -0.007  3.142  3.142 -3.142  0.007]
# Best parameters (sum to 1):	[-1.     1.    -0.002  1.     1.    -1.     0.002]
# ################################################################################
# Single trotterization step:
# ################################################################################
#
# All steps + measurements of state tomography:
# ################################################################################
#
# 1/8 - Job ID c508095c-ed45-487c-adb5-535c2c0eb099
# 2/8 - Job ID 9f814a7e-2c36-4a73-be9b-36a7c379d52a
# 3/8 - Job ID a2c084f1-2150-4c8f-a90d-f81b36db3ec4
# 4/8 - Job ID 948b4485-0666-49f9-b726-644f05c49abe
# 5/8 - Job ID fcf0f4d1-6654-40d7-9d22-a3e972afa8b0
# 6/8 - Job ID cb90dbc9-db43-49ef-a339-a891a44ffcc4
# 7/8 - Job ID 9cd04870-5724-4d2b-b8bb-2cc8c9bd23d9
# 8/8 - Job ID 474ee217-3f95-4166-96ad-aecb9b9a75f7
#
# ################################################################################
#
# Final results - order: 1 - strotter steps: 7
#
# State tomography fidelity = 0.7369 ± 0.0015
#
# ################################################################################
#
# Starting simulation for times from 0 to pi!
# Simulation ended!
# Total time of simulation: 00:01:42
# ################################################################################
# ================================================================================
# ################################################################################
#                                     Order: 1
#                                    # steps: 8
#                           min time: -3.141592653589793
# ################################################################################
# ================================================================================
# ################################################################################
# ################################################################################
#
# Starting optimization!
#
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.1
# ==================================================
#
# Iter 1 done!
# Loss value: -0.12967
# Current parameters: [-0.124  3.142  2.254  1.145 -1.82  -1.787 -2.052  2.385] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.21432
# Current parameters: [ 0.127  3.142  2.435  1.013 -1.991 -1.944 -1.911  2.272] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.37962
# Current parameters: [ 0.739  3.142  2.441  0.767 -2.121 -2.217 -1.954  2.346] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.12743
# Current parameters: [ 1.327  3.142  2.279  0.696 -2.167 -2.927 -1.806  2.599] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.42627
# Current parameters: [ 0.669  3.142  2.42   0.799 -2.049 -2.345 -1.936  2.442] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.32173
# Current parameters: [ 0.573  3.142  2.473  0.716 -1.894 -2.39  -1.882  2.404] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.43712
# Current parameters: [ 0.74   3.142  2.448  0.766 -2.056 -2.407 -1.923  2.432] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.44157
#             Iterations: 7
#             Function evaluations: 77
#             Gradient evaluations: 7
#
# Total time of optimization: 00:01:18
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.01
# ==================================================
#
# Iter 1 done!
# Loss value: -0.07188
# Current parameters: [-0.122  3.142  2.175  1.131 -1.745 -1.693 -2.145  2.398] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.18303
# Current parameters: [-0.061  2.828  2.336  1.074 -1.763 -1.698 -1.933  2.357] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.18193
# Current parameters: [ 0.146  2.435  2.597  0.957 -1.977 -1.883 -1.64   2.506] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.27257
# Current parameters: [ 0.095  2.435  2.488  1.172 -1.978 -1.98  -1.76   2.67 ] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.33712
# Current parameters: [ 0.28   2.421  2.511  1.176 -1.977 -2.028 -1.938  2.698] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.30293
# Current parameters: [ 0.461  2.748  2.325  1.064 -1.785 -1.888 -2.302  2.517] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.37721
# Current parameters: [ 0.57   2.579  2.355  1.159 -1.85  -2.01  -2.243  2.581] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.37942
# Current parameters: [ 0.491  2.557  2.397  1.149 -1.873 -1.996 -2.176  2.593] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.37872
# Current parameters: [ 0.451  2.569  2.409  1.133 -1.862 -1.975 -2.191  2.608] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.38025
# Current parameters: [ 0.481  2.564  2.403  1.142 -1.867 -1.983 -2.193  2.595] (sum to 3.14)
#
# Iter 11 done!
# Loss value: -0.36657
# Current parameters: [ 0.595  2.592  2.442  1.142 -1.841 -1.881 -2.432  2.525] (sum to 3.14)
#
# Iter 12 done!
# Loss value: -0.38232
# Current parameters: [ 0.515  2.573  2.436  1.141 -1.852 -1.945 -2.287  2.56 ] (sum to 3.14)
#
# Iter 13 done!
# Loss value: -0.19602
# Current parameters: [ 0.691  2.635  2.766  1.143 -1.738 -1.693 -2.944  2.282] (sum to 3.14)
#
# Iter 14 done!
# Loss value: -0.38286
# Current parameters: [ 0.537  2.576  2.503  1.145 -1.84  -1.892 -2.395  2.507] (sum to 3.14)
#
# Iter 15 done!
# Loss value: -0.38551
# Current parameters: [ 0.533  2.571  2.514  1.142 -1.843 -1.891 -2.388  2.504] (sum to 3.14)
#
# Iter 16 done!
# Loss value: -0.38826
# Current parameters: [ 0.534  2.503  2.702  1.124 -1.837 -1.807 -2.477  2.399] (sum to 3.14)
#
# Iter 17 done!
# Loss value: -0.39179
# Current parameters: [ 0.514  2.518  2.625  1.107 -1.848 -1.856 -2.374  2.456] (sum to 3.14)
#
# Iter 18 done!
# Loss value: -0.39534
# Current parameters: [ 0.521  2.515  2.652  1.095 -1.852 -1.821 -2.412  2.444] (sum to 3.14)
#
# Iter 19 done!
# Loss value: -0.39394
# Current parameters: [ 0.537  2.47   2.698  1.062 -1.864 -1.745 -2.451  2.436] (sum to 3.14)
#
# Iter 20 done!
# Loss value: -0.39841
# Current parameters: [ 0.545  2.477  2.676  1.048 -1.869 -1.748 -2.437  2.45 ] (sum to 3.14)
#
# Iter 21 done!
# Loss value: -0.40312
# Current parameters: [ 0.582  2.435  2.636  0.985 -1.876 -1.693 -2.426  2.498] (sum to 3.14)
#
# Iter 22 done!
# Loss value: -0.37904
# Current parameters: [ 0.781  2.302  2.416  0.727 -1.897 -1.487 -2.395  2.695] (sum to 3.14)
#
# Iter 23 done!
# Loss value: -0.41563
# Current parameters: [ 0.716  2.373  2.45   0.843 -1.874 -1.617 -2.39   2.64 ] (sum to 3.14)
#
# Iter 24 done!
# Loss value: -0.41734
# Current parameters: [ 0.745  2.372  2.415  0.834 -1.872 -1.615 -2.385  2.647] (sum to 3.14)
#
# Iter 25 done!
# Loss value: -0.41894
# Current parameters: [ 0.755  2.368  2.412  0.826 -1.856 -1.612 -2.377  2.627] (sum to 3.14)
#
# Iter 26 done!
# Loss value: -0.42862
# Current parameters: [ 0.819  2.348  2.45   0.782 -1.704 -1.616 -2.352  2.415] (sum to 3.14)
#
# Iter 27 done!
# Loss value: -0.43113
# Current parameters: [ 0.804  2.332  2.445  0.764 -1.677 -1.609 -2.331  2.413] (sum to 3.14)
#
# Iter 28 done!
# Loss value: -0.43206
# Current parameters: [ 0.767  2.327  2.43   0.788 -1.67  -1.596 -2.317  2.413] (sum to 3.14)
#
# Iter 29 done!
# Loss value: -0.43311
# Current parameters: [ 0.789  2.317  2.411  0.775 -1.649 -1.576 -2.322  2.397] (sum to 3.14)
#
# Iter 30 done!
# Loss value: -0.43412
# Current parameters: [ 0.797  2.325  2.41   0.781 -1.618 -1.554 -2.334  2.336] (sum to 3.14)
#
# Iter 31 done!
# Loss value: -0.43504
# Current parameters: [ 0.799  2.341  2.375  0.785 -1.639 -1.526 -2.353  2.36 ] (sum to 3.14)
#
# Iter 32 done!
# Loss value: -0.43544
# Current parameters: [ 0.786  2.346  2.37   0.78  -1.624 -1.527 -2.343  2.354] (sum to 3.14)
#
# Iter 33 done!
# Loss value: -0.43555
# Current parameters: [ 0.783  2.349  2.365  0.779 -1.608 -1.524 -2.344  2.34 ] (sum to 3.14)
#
# Iter 34 done!
# Loss value: -0.43565
# Current parameters: [ 0.781  2.357  2.365  0.781 -1.6   -1.525 -2.351  2.335] (sum to 3.14)
#
# Iter 35 done!
# Loss value: -0.4357
# Current parameters: [ 0.775  2.367  2.369  0.784 -1.589 -1.541 -2.361  2.338] (sum to 3.14)
#
# Iter 36 done!
# Loss value: -0.43573
# Current parameters: [ 0.775  2.367  2.369  0.784 -1.591 -1.545 -2.361  2.343] (sum to 3.14)
#
# Iter 37 done!
# Loss value: -0.43548
# Current parameters: [ 0.787  2.362  2.356  0.777 -1.591 -1.582 -2.358  2.391] (sum to 3.14)
#
# Iter 38 done!
# Loss value: -0.43579
# Current parameters: [ 0.779  2.363  2.366  0.782 -1.59  -1.555 -2.358  2.355] (sum to 3.14)
#
# Iter 39 done!
# Loss value: -0.43581
# Current parameters: [ 0.779  2.363  2.37   0.782 -1.586 -1.561 -2.358  2.353] (sum to 3.14)
#
# Iter 40 done!
# Loss value: -0.43581
# Current parameters: [ 0.779  2.363  2.368  0.781 -1.585 -1.559 -2.358  2.353] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.43581
#             Iterations: 40
#             Function evaluations: 380
#             Gradient evaluations: 40
#
# Total time of optimization: 00:06:30
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.001
# ==================================================
#
# Iter 1 done!
# Loss value: -0.07082
# Current parameters: [-0.127  3.142  2.169  1.171 -1.71  -1.67  -2.135  2.302] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.20024
# Current parameters: [-0.691  2.662  2.219  2.412 -2.41  -2.637 -0.889  2.476] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.2432
# Current parameters: [-0.768  2.878  2.139  2.348 -2.304 -2.82  -0.917  2.585] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.36587
# Current parameters: [-0.795  2.918  2.269  2.162 -2.202 -3.003 -0.745  2.538] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.37844
# Current parameters: [-0.752  2.901  2.327  2.259 -2.408 -2.875 -0.755  2.445] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.41874
# Current parameters: [-0.718  3.05   2.294  2.232 -2.408 -2.993 -0.681  2.366] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.42319
# Current parameters: [-0.705  3.098  2.245  2.296 -2.366 -3.017 -0.743  2.334] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.46999
# Current parameters: [-0.755  3.142  2.325  2.315 -2.383 -3.049 -0.759  2.307] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.47004
# Current parameters: [-0.745  3.142  2.333  2.324 -2.379 -3.074 -0.77   2.31 ] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.47059
# Current parameters: [-0.754  3.142  2.34   2.317 -2.376 -3.079 -0.78   2.331] (sum to 3.14)
# Iter 11 done!
# Loss value: -0.43431
# Current parameters: [-0.784  3.142  2.364  2.317 -2.354 -3.128 -0.808  2.391] (sum to 3.14)
#
# Iter 12 done!
# Loss value: -0.43267
# Current parameters: [-0.803  3.142  2.372  2.316 -2.343 -3.142 -0.816  2.415] (sum to 3.14)
#
# Iter 13 done!
# Loss value: -0.43021
# Current parameters: [-0.822  3.142  2.373  2.314 -2.336 -3.142 -0.814  2.427] (sum to 3.14)
#
# Iter 14 done!
# Loss value: -0.41801
# Current parameters: [-0.877  3.142  2.376  2.307 -2.315 -3.142 -0.811  2.461] (sum to 3.14)
#
# Iter 15 done!
# Loss value: -0.32439
# Current parameters: [-1.117  3.142  2.389  2.28  -2.224 -3.142 -0.795  2.608] (sum to 3.14)
#
# Iter 16 done!
# Loss value: -0.51003
# Current parameters: [-0.752  3.142  2.37   2.324 -2.36  -3.142 -0.818  2.378] (sum to 3.14)
#
# Iter 17 done!
# Loss value: -0.51122
# Current parameters: [-0.774  3.142  2.363  2.335 -2.352 -3.142 -0.807  2.377] (sum to 3.14)
#
# Iter 18 done!
# Loss value: -0.43213
# Current parameters: [-0.8    3.142  2.386  2.328 -2.358 -3.142 -0.774  2.36 ] (sum to 3.14)
#
# Iter 19 done!
# Loss value: -0.43351
# Current parameters: [-0.82   3.142  2.369  2.358 -2.363 -3.142 -0.783  2.382] (sum to 3.14)
#
# Iter 20 done!
# Loss value: -0.42368
# Current parameters: [-1.005  3.142  2.394  2.448 -2.41  -3.142 -0.689  2.403] (sum to 3.14)
#
# Iter 21 done!
# Loss value: -0.51179
# Current parameters: [-0.792  3.142  2.362  2.354 -2.352 -3.142 -0.796  2.366] (sum to 3.14)
#
# Iter 22 done!
# Loss value: -0.51155
# Current parameters: [-0.778  3.142  2.356  2.353 -2.347 -3.142 -0.798  2.355] (sum to 3.14)
#
# Iter 23 done!
# Loss value: -0.43576
# Current parameters: [-0.785  3.142  2.353  2.358 -2.353 -3.142 -0.788  2.357] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.51182
#             Iterations: 24
#             Function evaluations: 278
#             Gradient evaluations: 23
#
# Total time of optimization: 00:04:48
# Optimization results:
#   optimizer    eps                                       final_params  \
# 2     slsqp  0.001  [-0.787550722149227, 3.141592653589792, 2.3601...
# 0     slsqp  0.100  [0.7693646765465331, 3.141592653589793, 2.4156...
# 1     slsqp  0.010  [0.7792067061126501, 2.362620939103911, 2.3700...
#
#    final_loss
# 2    -0.51182
# 0    -0.44157
# 1    -0.43581
# Best parameters (sum to 3.14):	[-0.788  3.142  2.36   2.354 -2.35  -3.142 -0.796  2.362]
# Best parameters (sum to 1):	[-0.251  1.     0.751  0.749 -0.748 -1.    -0.254  0.752]
# ################################################################################
# Single trotterization step:
# ################################################################################
#
# All steps + measurements of state tomography:
# ################################################################################
#
# 1/8 - Job ID aad794ef-68c6-4a86-9b3b-57951d7c9270
# 2/8 - Job ID 13da262e-01b4-487e-bb1e-d45f3e8eb85c
# 3/8 - Job ID c6fe23bd-c9cc-4aa9-a814-56e7f92f16f0
# 4/8 - Job ID 5814ab65-281f-430d-8edf-525aa57a138d
# 5/8 - Job ID b1159afa-79a1-4ebb-a236-2f594600fa77
# 6/8 - Job ID a51ab65a-f5b9-4559-b9b4-3a68274fc1a4
# 7/8 - Job ID 793d6019-b9d0-4d15-9693-fd4cb3e7cfaf
# 8/8 - Job ID 810534b8-9c6d-487c-9626-fe770bcdaf4f
#
# ################################################################################
#
# Final results - order: 1 - strotter steps: 8
#
# State tomography fidelity = 0.5107 ± 0.0019
#
# ################################################################################
#
# Starting simulation for times from 0 to pi!
# Simulation ended!
# Total time of simulation: 00:01:50

# %%
results_first_order = pd.DataFrame(results).sort_values("fid_pi", ascending=False)

results_first_order
# Out:
#    order  n_steps     t_min  \
# 1      1        5 -3.141593
# 0      1        4 -3.141593
# 2      1        6 -3.141593
# 4      1        8 -3.141593
# 3      1        7 -3.141593
#
#                                      state_tomo_fids   fid_pi  \
# 1  [0.6724571077943378, 0.6720071817307735, 0.669...  0.67132
# 0  [0.6170661575732186, 0.6153063029918728, 0.612...  0.61512
# 2  [0.5632750874531569, 0.5651981259045604, 0.563...  0.56428
# 4  [0.511671029262871, 0.513009196383594, 0.51145...  0.51182
# 3  [0.7382165181855109, 0.7374833830608148, 0.734...   0.4798
#
#                                          best_params
# 1  [0.01479146504227919, 3.141592653589793, 1.556...
# 0  [-0.0052939301769448855, 1.576439440713225, 1....
# 2  [-0.0022995687072801868, 3.141592653589793, 1....
# 4  [-0.787550722149227, 3.141592653589792, 2.3601...
# 3  [-3.1415926535897927, 3.141592653589793, -0.00...

# %%
results_first_order["fid_pi"] = results_first_order["fid_pi"].astype("float")

file_1st = f"results/results_opt_first_order_{dt.datetime.today().date()}.parquet"

results_first_order.to_parquet(file_1st, index=False)

# %% [markdown]
# ___________

# %% [markdown]
# ## Second order
#
# - Steps: 4 to 8;
# - Variable time;
# - Minimum time: 0.001 and 0.0005;

# %%
results = {"order" : [],
           "n_steps" : [],
           "t_min" : [],
           "state_tomo_fids" : [],
           "fid_pi" : [],
           "best_params" : []}

# %%
order = 2
uniform_times = False
backend_opt, backend_state_tomo = sim_noisy_jakarta, sim_noisy_jakarta
quadratic_loss = False

steps = range(4, 9)
min_times = [-np.pi]

combs = itertools.product(steps, min_times)

for trotter_steps, params_bounds_min in combs:
    
    print("\n\n")    
    print("#"*80)
    print("="*80)
    print("#"*80)
    print(f"Order: {order}".center(80))
    print(f"# steps: {trotter_steps}".center(80))
    print(f"min time: {params_bounds_min}".center(80))
    print("#"*80)
    print("="*80)
    print("#"*80)
    print("\n\n")
    
    fids, fidelity_pi, best_params = optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                                                             backend_opt, backend_state_tomo, quadratic_loss)
    
    results['order'].append(order)
    results['n_steps'].append(trotter_steps)
    results['t_min'].append(params_bounds_min)
    results['state_tomo_fids'].append(fids)
    results['fid_pi'].append(fidelity_pi)
    results['best_params'].append(best_params)
# Out:
# ################################################################################
# ================================================================================
# ################################################################################
#                                     Order: 2
#                                    # steps: 4
#                           min time: -3.141592653589793
# ################################################################################
# ================================================================================
# ################################################################################
# ################################################################################
#
# Starting optimization!
#
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.1
# ==================================================
#
# Iter 1 done!
# Loss value: -0.36779
# Current parameters: [-1.006  2.409  1.376  0.363] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.41022
# Current parameters: [-1.107  2.401  1.251  0.596] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.41737
# Current parameters: [-1.163  2.336  1.219  0.75 ] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.44924
# Current parameters: [-1.398  1.763  0.967  1.81 ] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.4719
# Current parameters: [-1.486  1.776  1.064  1.787] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.44056
# Current parameters: [-1.999  1.71   1.462  1.969] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.49299
# Current parameters: [-1.626  1.908  1.32   1.54 ] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.49925
# Current parameters: [-1.662  1.81   1.28   1.713] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.5029
# Current parameters: [-1.683  1.833  1.343  1.649] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.50552
# Current parameters: [-1.71   1.828  1.43   1.593] (sum to 3.14)
#
# Iter 11 done!
# Loss value: -0.50842
# Current parameters: [-1.712  1.791  1.473  1.59 ] (sum to 3.14)
#
# Iter 12 done!
# Loss value: -0.5162
# Current parameters: [-1.638  1.6    1.624  1.555] (sum to 3.14)
#
# Iter 13 done!
# Loss value: -0.51899
# Current parameters: [-1.573  1.559  1.61   1.546] (sum to 3.14)
#
# Iter 14 done!
# Loss value: -0.51942
# Current parameters: [-1.573  1.576  1.57   1.569] (sum to 3.14)
#
# Iter 15 done!
# Loss value: -0.51942
# Current parameters: [-1.57   1.572  1.573  1.566] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.51942
#             Iterations: 15
#             Function evaluations: 87
#             Gradient evaluations: 15
#
# Total time of optimization: 00:01:28
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.01
# ==================================================
#
# Iter 1 done!
# Loss value: -0.35002
# Current parameters: [-0.989  2.399  1.399  0.332] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.41202
# Current parameters: [-1.093  2.361  1.3    0.573] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.41977
# Current parameters: [-1.159  2.327  1.306  0.668] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.43663
# Current parameters: [-1.359  2.205  1.361  0.935] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.40445
# Current parameters: [-2.723  1.537  1.79   2.537] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.45891
# Current parameters: [-1.619  2.077  1.448  1.235] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.49331
# Current parameters: [-1.857  1.92   1.515  1.564] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.51074
# Current parameters: [-1.648  1.765  1.43   1.594] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.50897
# Current parameters: [-1.506  1.618  1.385  1.645] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.51436
# Current parameters: [-1.589  1.653  1.429  1.649] (sum to 3.14)
#
# Iter 11 done!
# Loss value: -0.51523
# Current parameters: [-1.596  1.654  1.446  1.638] (sum to 3.14)
#
# Iter 12 done!
# Loss value: -0.51573
# Current parameters: [-1.616  1.554  1.665  1.539] (sum to 3.14)
#
# Iter 13 done!
# Loss value: -0.51939
# Current parameters: [-1.568  1.576  1.568  1.566] (sum to 3.14)
#
# Iter 14 done!
# Loss value: -0.51942
# Current parameters: [-1.568  1.57   1.571  1.568] (sum to 3.14)
#
# Iter 15 done!
# Loss value: -0.51942
# Current parameters: [-1.571  1.569  1.573  1.57 ] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.51942
#             Iterations: 15
#             Function evaluations: 91
#             Gradient evaluations: 15
#
# Total time of optimization: 00:01:31
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.001
# ==================================================
#
# Iter 1 done!
# Loss value: -0.3663
# Current parameters: [-0.963  2.407  1.343  0.355] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.41253
# Current parameters: [-1.038  2.366  1.198  0.615] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.42289
# Current parameters: [-1.042  2.303  1.184  0.697] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.43981
# Current parameters: [-0.874  1.434  0.791  1.791] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.45353
# Current parameters: [-0.989  2.091  1.081  0.959] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.45374
# Current parameters: [-0.965  2.127  1.082  0.898] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.45475
# Current parameters: [-0.952  2.11   1.068  0.915] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.45521
# Current parameters: [-0.901  2.087  1.037  0.918] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.45531
# Current parameters: [-0.914  2.091  1.044  0.92 ] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.38283
# Current parameters: [-3.142  2.864  2.331  1.088] (sum to 3.14)
#
# Iter 11 done!
# Loss value: -0.45535
# Current parameters: [-0.915  2.092  1.045  0.919] (sum to 3.14)
#
# Iter 12 done!
# Loss value: -0.45484
# Current parameters: [-0.877  2.095  1.018  0.905] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.45535
#             Iterations: 12
#             Function evaluations: 77
#             Gradient evaluations: 12
#
# Total time of optimization: 00:01:11
# Optimization results:
#   optimizer    eps                                       final_params  \
# 0     slsqp  0.100  [-1.5732932030040132, 1.5760237804289736, 1.57...
# 1     slsqp  0.010  [-1.5680659009710358, 1.5701778134380269, 1.57...
# 2     slsqp  0.001  [-0.9151091669661481, 2.092373012191301, 1.045...
#
#    final_loss
# 0    -0.51942
# 1    -0.51942
# 2    -0.45535
# Best parameters (sum to 3.14):	[-1.573  1.576  1.57   1.569]
# Best parameters (sum to 1):	[-0.501  0.502  0.5    0.499]
# ################################################################################
# Single trotterization step:
# ################################################################################
#
# All steps + measurements of state tomography:
# ################################################################################
#
# 1/8 - Job ID d1b5054e-e1a4-49c8-ac80-dee045f635c4
# 2/8 - Job ID 9b88a6ec-3e56-4490-b0e6-61a487c56d08
# 3/8 - Job ID f2b4fbc0-4d97-46b4-8ba3-c1f27168f720
# 4/8 - Job ID 6faf99c4-1416-4155-8996-73a1b39bcd6d
# 5/8 - Job ID 355dd895-04a2-4e3e-8f5b-a15167e543a3
# 6/8 - Job ID 57355b7f-ebe5-4081-8313-dd4a9b019ec4
# 7/8 - Job ID 8d22c047-00d2-48b1-8865-5d8aee36b85d
# 8/8 - Job ID b01fd5b3-dbc3-4da8-8b67-50674abd9e38
#
# ################################################################################
#
# Final results - order: 2 - strotter steps: 4
#
# State tomography fidelity = 0.5166 ± 0.0026
#
# ################################################################################
#
# Starting simulation for times from 0 to pi!
# Simulation ended!
# Total time of simulation: 00:01:32
# ################################################################################
# ================================================================================
# ################################################################################
#                                     Order: 2
#                                    # steps: 5
#                           min time: -3.141592653589793
# ################################################################################
# ================================================================================
# ################################################################################
# ################################################################################
#
# Starting optimization!
#
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.1
# ==================================================
#
# Iter 1 done!
# Loss value: -0.36296
# Current parameters: [-0.537  3.142  1.692  0.836 -1.991] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.37775
# Current parameters: [-0.528  3.142  1.709  0.748 -1.93 ] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.3832
# Current parameters: [-0.31   3.142  1.631  0.105 -1.426] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.42668
# Current parameters: [-0.365  3.142  1.632  0.464 -1.73 ] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.43763
# Current parameters: [-0.249  3.142  1.544  0.363 -1.658] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.44543
# Current parameters: [-0.183  3.142  1.545  0.292 -1.654] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.42284
# Current parameters: [ 0.483  3.142  1.495 -0.493 -1.485] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.47184
# Current parameters: [-0.022  3.142  1.542  0.083 -1.603] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.47392
# Current parameters: [ 0.006  3.142  1.541  0.047 -1.594] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.47268
# Current parameters: [ 2.702e-03  3.142e+00  1.540e+00  5.677e-02 -1.599e+00] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.47392
#             Iterations: 10
#             Function evaluations: 74
#             Gradient evaluations: 10
#
# Total time of optimization: 00:01:16
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.01
# ==================================================
#
# Iter 1 done!
# Loss value: -0.37049
# Current parameters: [-0.569  3.142  1.71   0.822 -1.963] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.38175
# Current parameters: [-0.607  3.142  1.756  0.738 -1.887] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.39711
# Current parameters: [-0.613  3.142  1.71   0.669 -1.766] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.2204
# Current parameters: [-0.511  3.142  1.181  0.083 -0.753] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.41938
# Current parameters: [-0.541  3.142  1.589  0.571 -1.619] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.42274
# Current parameters: [-0.349  3.142  1.545  0.488 -1.684] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.43531
# Current parameters: [-0.326  3.142  1.556  0.419 -1.649] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.46218
# Current parameters: [-0.179  3.142  1.566  0.191 -1.578] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.16254
# Current parameters: [ 2.273  3.142  1.661 -3.142 -0.792] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.47724
# Current parameters: [-0.04   3.142  1.591  0.026 -1.577] (sum to 3.14)
#
# Iter 11 done!
# Loss value: -0.47784
# Current parameters: [-0.018  3.142  1.589  0.01  -1.582] (sum to 3.14)
#
# Iter 12 done!
# Loss value: -0.47741
# Current parameters: [ 0.04   3.142  1.557 -0.032 -1.566] (sum to 3.14)
#
# Iter 13 done!
# Loss value: -0.47808
# Current parameters: [ 2.890e-03  3.142e+00  1.570e+00  1.039e-03 -1.574e+00] (sum to 3.14)
#
# Iter 14 done!
# Loss value: -0.47807
# Current parameters: [ 5.012e-03  3.142e+00  1.571e+00 -1.165e-03 -1.575e+00] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.47808
#             Iterations: 14
#             Function evaluations: 99
#             Gradient evaluations: 14
#
# Total time of optimization: 00:01:44
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.001
# ==================================================
#
# Iter 1 done!
# Loss value: -0.37133
# Current parameters: [-0.575  3.142  1.711  0.823 -1.958] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.38044
# Current parameters: [-0.615  3.142  1.75   0.763 -1.898] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.38355
# Current parameters: [-0.66   3.142  1.749  0.754 -1.842] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.46524
# Current parameters: [-3.142  3.142  1.394  0.101  1.646] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.4677
# Current parameters: [-3.142  3.142  1.49  -0.09   1.742] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.44722
# Current parameters: [-3.142  3.142  1.452 -0.004  1.694] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.48594
# Current parameters: [-3.142  3.142  1.484 -0.028  1.685] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.45174
# Current parameters: [-3.142  3.142  1.605 -0.074  1.611] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.32756
# Current parameters: [-3.142  3.142  2.088 -0.259  1.312] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.42929
# Current parameters: [-3.142  3.142  3.142 -0.654  0.654] (sum to 3.14)
#
# Iter 11 done!
# Loss value: -0.42964
# Current parameters: [-3.142  3.142  3.142 -0.64   0.64 ] (sum to 3.14)
#
# Iter 12 done!
# Loss value: -0.43016
# Current parameters: [-3.142  3.142  3.142 -0.624  0.624] (sum to 3.14)
#
# Iter 13 done!
# Loss value: -0.48399
# Current parameters: [-3.142  3.142  3.142 -0.6    0.6  ] (sum to 3.14)
#
# Iter 14 done!
# Loss value: -0.46473
# Current parameters: [-3.142  3.142  1.626  0.108  1.407] (sum to 3.14)
#
# Iter 15 done!
# Loss value: -0.49727
# Current parameters: [-3.142  3.142  1.58  -0.004  1.566] (sum to 3.14)
#
# Iter 16 done!
# Loss value: -0.49727
# Current parameters: [-3.142  3.142  1.58  -0.004  1.566] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.49727
#             Iterations: 17
#             Function evaluations: 172
#             Gradient evaluations: 16
#
# Total time of optimization: 00:02:51
# Optimization results:
#   optimizer    eps                                       final_params  \
# 2     slsqp  0.001  [-3.141592653589793, 3.141592653589793, 1.5799...
# 1     slsqp  0.010  [0.0028907179927954913, 3.1415926535897922, 1....
# 0     slsqp  0.100  [0.005610659178939734, 3.141592653589793, 1.54...
#
#    final_loss
# 2    -0.49727
# 1    -0.47808
# 0    -0.47392
# Best parameters (sum to 3.14):	[-3.142  3.142  1.58  -0.004  1.566]
# Best parameters (sum to 1):	[-1.     1.     0.503 -0.001  0.498]
# ################################################################################
# Single trotterization step:
# ################################################################################
#
# All steps + measurements of state tomography:
# ################################################################################
#
# 1/8 - Job ID 694986a7-a19a-4b85-9c36-1d184e124ad4
# 2/8 - Job ID 3f2e48c1-4753-46e9-88f2-cd86a29e5324
# 3/8 - Job ID db0e79c0-bab8-43bb-b56b-b296f4218a8c
# 4/8 - Job ID 8d55cfc9-8857-4aec-810b-a0b665212e77
# 5/8 - Job ID f0be18d4-ffe9-4821-b865-7ffff24c0ffd
# 6/8 - Job ID f399a176-b0ff-48de-9405-2d6ae81a3a5b
# 7/8 - Job ID 47a71367-268c-4750-bab3-fd50be0b464d
# 8/8 - Job ID 3c3ccf89-0f61-418a-8a13-9d3167d57f1e
#
# ################################################################################
#
# Final results - order: 2 - strotter steps: 5
#
# State tomography fidelity = 0.4962 ± 0.0026
#
# ################################################################################
#
# Starting simulation for times from 0 to pi!
# Simulation ended!
# Total time of simulation: 00:01:43
# ################################################################################
# ================================================================================
# ################################################################################
#                                     Order: 2
#                                    # steps: 6
#                           min time: -3.141592653589793
# ################################################################################
# ================================================================================
# ################################################################################
# ################################################################################
#
# Starting optimization!
#
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.1
# ==================================================
#
# Iter 1 done!
# Loss value: -0.30593
# Current parameters: [-0.27   3.142  2.134  1.055 -1.482 -1.438] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.36153
# Current parameters: [ 0.149  3.142  2.095  0.952 -1.608 -1.587] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.39421
# Current parameters: [ 0.019  3.142  2.172  1.03  -1.615 -1.606] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.39424
# Current parameters: [ 0.032  3.142  2.17   1.008 -1.617 -1.594] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.39402
# Current parameters: [ 0.033  3.142  2.183  0.994 -1.625 -1.586] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.39434
#             Iterations: 5
#             Function evaluations: 47
#             Gradient evaluations: 5
#
# Total time of optimization: 00:00:51
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.01
# ==================================================
#
# Iter 1 done!
# Loss value: -0.32259
# Current parameters: [-0.244  3.142  2.128  1.08  -1.508 -1.457] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.35982
# Current parameters: [ 0.152  3.142  2.064  0.982 -1.607 -1.591] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.39879
# Current parameters: [-0.01   3.142  2.122  1.041 -1.577 -1.576] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.39915
# Current parameters: [-0.005  3.142  2.116  1.024 -1.573 -1.562] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.39917
# Current parameters: [-0.005  3.142  2.108  1.025 -1.568 -1.561] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.39926
# Current parameters: [-0.006  3.142  2.105  1.031 -1.564 -1.566] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.39932
# Current parameters: [-0.019  3.142  2.062  1.095 -1.541 -1.598] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.39961
# Current parameters: [-0.007  3.142  2.08   1.061 -1.553 -1.58 ] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.39835
# Current parameters: [ 0.018  3.142  2.028  1.067 -1.547 -1.566] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.39997
# Current parameters: [ 8.906e-04  3.142e+00  2.042e+00  1.084e+00 -1.544e+00 -1.583e+00] (sum to 3.14)
#
# Iter 11 done!
# Loss value: -0.41642
# Current parameters: [ 0.048  3.142  1.608  1.44  -1.396 -1.7  ] (sum to 3.14)
#
# Iter 12 done!
# Loss value: -0.41593
# Current parameters: [ 0.036  3.142  1.494  1.514 -1.352 -1.692] (sum to 3.14)
#
# Iter 13 done!
# Loss value: -0.40639
# Current parameters: [-0.066  3.142  1.656  1.329 -1.419 -1.501] (sum to 3.14)
#
# Iter 14 done!
# Loss value: -0.42267
# Current parameters: [ 0.01   3.142  1.57   1.464 -1.411 -1.632] (sum to 3.14)
#
# Iter 15 done!
# Loss value: -0.42527
# Current parameters: [ 0.009  3.142  1.597  1.475 -1.46  -1.621] (sum to 3.14)
#
# Iter 16 done!
# Loss value: -0.38193
# Current parameters: [-0.014  3.142  1.787  1.722 -2.066 -1.429] (sum to 3.14)
#
# Iter 17 done!
# Loss value: -0.42798
# Current parameters: [ 0.006  3.142  1.598  1.532 -1.548 -1.587] (sum to 3.14)
#
# Iter 18 done!
# Loss value: -0.42825
# Current parameters: [ 0.006  3.142  1.582  1.543 -1.543 -1.588] (sum to 3.14)
#
# Iter 19 done!
# Loss value: -0.42361
# Current parameters: [ 0.005  3.142  1.462  1.674 -1.577 -1.564] (sum to 3.14)
#
# Iter 20 done!
# Loss value: -0.42849
# Current parameters: [ 0.005  3.142  1.562  1.569 -1.557 -1.579] (sum to 3.14)
#
# Iter 21 done!
# Loss value: -0.42853
# Current parameters: [ 0.005  3.142  1.566  1.566 -1.559 -1.578] (sum to 3.14)

# %%
results_second_order = pd.DataFrame(results).sort_values("fid_pi", ascending=False)

results_second_order

# %%
results_second_order["fid_pi"] = results_second_order["fid_pi"].astype("float")

file_2nd = f"results/results_opt_second_order_{dt.datetime.today().date()}.parquet"

results_second_order.to_parquet(file_2nd, index=False)

# %% [markdown]
# ___________
#
# # Hardware execution
#
# After we have the optimized parameters for all combinations above

# %%
result_files = [f for f in listdir("./results") if isfile(join("./results", f))]

result_files

# %%
results_1st_order = pd.read_parquet('./results/results_opt_first_order_2022-04-08.parquet')

results_1st_order

# %%
results_2nd_order = pd.read_parquet('results/results_opt_second_order_2022-04-06.parquet')

results_2nd_order

# %% [markdown]
# _____________
#
# ### Execution - 1st order

# %%
jobs_dict_1st_order = send_jobs(results_1st_order, jakarta, uniform_times=False)

jobs_dict_1st_order

# %%
jobs_dict_1st_order_ids = {}

for k, v in jobs_dict_1st_order.items():
    
    ids = [x._job_id for x in v]
    
    jobs_dict_1st_order_ids[k] = ids
    
with open('results/dict_jobs_ids_first_order_2022-04-08.pkl', 'wb') as f:
    pickle.dump(jobs_dict_1st_order_ids, f)
    
jobs_dict_1st_order_ids

# %%
# fids_dict_1st_order = hardware_exec_final_analysis(jobs_dict_1st_order)

# %% [markdown]
# _____________
#
# ### Execution - 2nd order

# %%
jobs_dict_2nd_order = send_jobs(results_2nd_order, jakarta, uniform_times=False)

jobs_dict_2nd_order

# %%
jobs_dict_2nd_order_ids = {}

for k, v in jobs_dict_2nd_order.items():
    
    ids = [x._job_id for x in v]
    
    jobs_dict_2nd_order_ids[k] = ids
    
with open('results/dict_jobs_ids_second_order_2022-04-06.pkl', 'wb') as f:
    pickle.dump(jobs_dict_2nd_order_ids, f)
    
jobs_dict_2nd_order_ids

# %%
# fids_dict_2nd_order = hardware_exec_final_analysis(jobs_dict_2nd_order)
