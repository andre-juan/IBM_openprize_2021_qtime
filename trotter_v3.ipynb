# %% [markdown]
# # v3 - QML optimization + execution of circuit with best params
#
# Now trying different constraints
# ___________________
# ___________________
# ___________________

# %%
# %load_ext autoreload
# %autoreload 2

from troter_utils import *

# %% [markdown]
# ### Quantum Devices

# %%
# load IBMQ Account data
provider = IBMQ.load_account()

# Get backend for experiment
provider = IBMQ.get_provider(hub='ibm-q-community', group='ibmquantumawards', project='open-science-22')
jakarta = provider.get_backend('ibmq_jakarta')

# Simulated backend based on ibmq_jakarta's device noise profile
sim_noisy_jakarta = QasmSimulator.from_backend(provider.get_backend('ibmq_jakarta'))

# Noiseless simulated backend
sim_no_noise = QasmSimulator()

# %% [markdown]
# ____________

# %% [markdown]
# ### First order, 4 steps, variable time, params_bounds_min=0

# %%
order, trotter_steps = 1, 4
uniform_times = False
params_bounds_min = 0
backend_opt, backend_state_tomo = sim_noisy_jakarta, sim_noisy_jakarta

optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                        backend_opt, backend_state_tomo)
# Out:
# ################################################################################
#
# Starting optimization!
#
#
# ...
# Optimizer: SLSQP
# eps = 0.1
# ...
#
# Iter 1 done!
# Loss value: -0.30317
# Current parameters: [6.661e-16 1.628e+00 4.277e-01 1.086e+00] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.66966
# Current parameters: [0.000e+00 1.374e+00 1.110e-16 1.767e+00] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.70643
# Current parameters: [9.714e-17 1.508e+00 3.266e-16 1.634e+00] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.70747
# Current parameters: [1.631e-16 1.527e+00 2.736e-16 1.614e+00] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.70828
# Current parameters: [0.    1.562 0.    1.579] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.70831
# Current parameters: [1.214e-17 1.576e+00 9.482e-17 1.566e+00] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.70832
# Current parameters: [1.930e-17 1.572e+00 0.000e+00 1.570e+00] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.70832
# ...

# %% [markdown]
# ## Sending job to hardware execution

# %%
order, trotter_steps = 1, 4
uniform_times = False
params_bounds_min = 0
backend_opt, backend_state_tomo = sim_noisy_jakarta, jakarta

optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                        backend_opt, backend_state_tomo)
# Out:
# ################################################################################
#
# Starting optimization!
#
#
# ...
# Optimizer: SLSQP
# eps = 0.1
# ...
#
# Iter 1 done!
# Loss value: -0.31286
# Current parameters: [0.    1.627 0.423 1.092] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.66569
# Current parameters: [0.    1.363 0.    1.779] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.71058
# Current parameters: [5.551e-17 1.512e+00 1.228e-16 1.629e+00] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.71135
# Current parameters: [1.769e-16 1.531e+00 0.000e+00 1.611e+00] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.71202
# Current parameters: [0.    1.574 0.    1.567] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.71203
# Current parameters: [2.329e-16 1.571e+00 2.319e-16 1.571e+00] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.71203
# Current parameters: [3.762e-17 1.571e+00 0.000e+00 1.570e+00] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
# ...

# %% [markdown]
# ### First order, 4 steps, variable time, params_bounds_min=0.1

# %%
order, trotter_steps = 1, 4
uniform_times = False
params_bounds_min = 0.1
backend_opt, backend_state_tomo = sim_noisy_jakarta, sim_noisy_jakarta

optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                        backend_opt, backend_state_tomo)
# Out:
# ################################################################################
#
# Starting optimization!
#
#
# ...
# Optimizer: SLSQP
# eps = 0.1
# ...
#
# Iter 1 done!
# Loss value: -0.15944
# Current parameters: [0.1   1.48  0.525 1.036] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.55665
# Current parameters: [0.1   1.529 0.1   1.412] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.56161
# Current parameters: [0.1   1.417 0.1   1.524] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.5627
# Current parameters: [0.1   1.437 0.1   1.504] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.56274
# Current parameters: [0.1   1.438 0.1   1.504] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.56274
# Current parameters: [0.1   1.438 0.1   1.504] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.56274
#             Iterations: 6
#             Function evaluations: 41
#             Gradient evaluations: 6
#
# ...

# %% [markdown]
# ### First order, 4 steps, variable time, params_bounds_min=0.5

# %%
order, trotter_steps = 1, 4
uniform_times = False
params_bounds_min = 0.5
backend_opt, backend_state_tomo = sim_noisy_jakarta, sim_noisy_jakarta

optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                        backend_opt, backend_state_tomo)
# Out:
# ################################################################################
#
# Starting optimization!
#
#
# ...
# Optimizer: SLSQP
# eps = 0.1
# ...
#
# Iter 1 done!
# Loss value: -0.05057
# Current parameters: [0.5   1.26  0.881 0.5  ] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.05008
# Current parameters: [0.501 1.265 0.875 0.5  ] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.05057
#             Iterations: 2
#             Function evaluations: 21
#             Gradient evaluations: 2
#
# Total time of optimization: 00:00:17
#
# ...
# Optimizer: SLSQP
# eps = 0.01
# ...
#
# Iter 1 done!
# Loss value: -0.0523
# Current parameters: [0.5   1.28  0.805 0.557] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.07371
# Current parameters: [0.554 1.291 0.703 0.594] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.10268
# Current parameters: [0.646 1.333 0.5   0.662] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.11851
# ...

# %% [markdown]
# ### First order, 4 steps, variable time, params_bounds_min=-pi (allowing negative times)

# %%
order, trotter_steps = 1, 4
uniform_times = False
params_bounds_min = -np.pi
backend_opt, backend_state_tomo = sim_noisy_jakarta, sim_noisy_jakarta

optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                        backend_opt, backend_state_tomo)
# Out:
# ################################################################################
#
# Starting optimization!
#
#
# ...
# Optimizer: SLSQP
# eps = 0.1
# ...
#
# Iter 1 done!
# Loss value: -0.23322
# Current parameters: [-1.237  2.176  1.048  1.155] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.04245
# Current parameters: [-0.596  1.5    1.454  0.783] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.08201
# Current parameters: [-0.497  1.526  1.421  0.691] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.15632
# Current parameters: [ 0.621  1.828  1.261 -0.569] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.56862
# Current parameters: [-0.084  1.602  1.539  0.085] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.57372
# Current parameters: [-0.037  1.61   1.557  0.011] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.574
# Current parameters: [-0.019  1.604  1.56  -0.003] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.57406
# Current parameters: [-0.01   1.595  1.56  -0.003] (sum to 3.14)
#
# ...

# %% [markdown]
# ___________

# %% [markdown]
# ### First order, 5 steps, variable time, params_bounds_min=0

# %%
order, trotter_steps = 1, 5
uniform_times = False
params_bounds_min = 0
backend_opt, backend_state_tomo = sim_noisy_jakarta, sim_noisy_jakarta

optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                        backend_opt, backend_state_tomo)
# Out:
# ################################################################################
#
# Starting optimization!
#
#
# ...
# Optimizer: SLSQP
# eps = 0.1
# ...
#
# Iter 1 done!
# Loss value: -0.03217
# Current parameters: [0.000e+00 1.788e+00 8.464e-01 5.076e-01 4.996e-16] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.33339
# Current parameters: [2.483e-17 1.618e+00 1.065e+00 2.683e-01 1.902e-01] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.07896
# Current parameters: [2.234e-16 3.655e-01 1.985e+00 0.000e+00 7.907e-01] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.61242
# Current parameters: [1.098e-17 1.588e+00 1.388e+00 2.776e-17 1.661e-01] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.62208
# Current parameters: [0.    1.563 1.43  0.    0.148] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.62953
# Current parameters: [0.    1.55  1.478 0.    0.114] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.63348
# ...

# %% [markdown]
# ### First order, 5 steps, variable time, params_bounds_min=0.1

# %%
order, trotter_steps = 1, 5
uniform_times = False
params_bounds_min = 0.1
backend_opt, backend_state_tomo = sim_noisy_jakarta, sim_noisy_jakarta

optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                        backend_opt, backend_state_tomo)
# Out:
# ################################################################################
#
# Starting optimization!
#
#
# ...
# Optimizer: SLSQP
# eps = 0.1
# ...
#
# Iter 1 done!
# Loss value: -0.21321
# Current parameters: [0.1   1.522 1.014 0.405 0.1  ] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.37699
# Current parameters: [0.1   1.223 1.458 0.1   0.261] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.48297
# Current parameters: [0.1   1.344 1.497 0.1   0.1  ] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.49038
# Current parameters: [0.1   1.413 1.428 0.1   0.1  ] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.49048
# Current parameters: [0.1   1.436 1.405 0.1   0.1  ] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.49053
# Current parameters: [0.1   1.434 1.408 0.1   0.1  ] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.49052
# Current parameters: [0.1   1.434 1.407 0.1   0.1  ] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
# ...

# %% [markdown]
# ### First order, 5 steps, variable time, params_bounds_min=-pi (allowing negative times)

# %%
order, trotter_steps = 1, 5
uniform_times = False
params_bounds_min = -np.pi
backend_opt, backend_state_tomo = sim_noisy_jakarta, sim_noisy_jakarta

optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                        backend_opt, backend_state_tomo)
# Out:
# ################################################################################
#
# Starting optimization!
#
#
# ...
# Optimizer: SLSQP
# eps = 0.1
# ...
#
# Iter 1 done!
# Loss value: -0.04933
# Current parameters: [-0.279  3.017  1.784  0.815 -2.196] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.09246
# Current parameters: [-0.397  2.95   1.857  0.966 -2.235] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.14638
# Current parameters: [-0.601  2.648  2.11   1.477 -2.492] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.04772
# Current parameters: [-0.713  2.162  2.182  2.487 -2.977] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.24305
# Current parameters: [-0.546  2.561  1.835  1.926 -2.634] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.27467
# Current parameters: [-0.266  2.669  1.697  1.665 -2.624] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.36285
# Current parameters: [-0.263  2.763  1.768  1.698 -2.825] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.52491
# ...

# %%
order, trotter_steps = 1, 7
uniform_times = False
params_bounds_min = -np.pi
backend_opt, backend_state_tomo = sim_noisy_jakarta, sim_noisy_jakarta

optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                        backend_opt, backend_state_tomo)
# Out:
# ################################################################################
#
# Starting optimization!
#
#
# ...
# Optimizer: SLSQP
# eps = 0.1
# ...
#
# Iter 1 done!
# Loss value: -0.08957
# Current parameters: [ 0.232  3.142  2.313  1.592 -1.225 -0.99  -1.922] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.15486
# Current parameters: [ 0.411  2.95   2.264  1.692 -1.099 -1.156 -1.92 ] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.11433
# Current parameters: [ 1.893  1.401  2.154  2.595 -0.788 -2.    -2.113] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.3686
# Current parameters: [ 0.966  2.518  2.224  2.043 -0.9   -1.491 -2.219] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.31847
# Current parameters: [ 0.632  2.637  2.37   2.008 -0.934 -1.391 -2.181] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.39893
# Current parameters: [ 0.689  2.517  2.334  2.193 -0.852 -1.415 -2.324] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.42102
# ...
