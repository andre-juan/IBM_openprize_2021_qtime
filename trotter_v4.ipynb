# %% [markdown]
# # v4 - QML optimization + execution of circuit with best params
#
# Now trying different constraints
#
# And also trying a quadratic loss!
# ___________________
# ___________________
# ___________________

# %%
# %load_ext autoreload
# %autoreload 2

from troter_utils import *

# %% [markdown]
# ### Quantum Devices

# %%
# load IBMQ Account data
provider = IBMQ.load_account()

# Get backend for experiment
provider = IBMQ.get_provider(hub='ibm-q-community', group='ibmquantumawards', project='open-science-22')
jakarta = provider.get_backend('ibmq_jakarta')

# Simulated backend based on ibmq_jakarta's device noise profile
sim_noisy_jakarta = QasmSimulator.from_backend(provider.get_backend('ibmq_jakarta'))

# Noiseless simulated backend
sim_no_noise = QasmSimulator()

# %% [markdown]
# ____________

# %% [markdown]
# ### First order, 4 steps, variable time, params_bounds_min=0

# %%
order, trotter_steps = 1, 4
uniform_times = False
params_bounds_min = 0
backend_opt, backend_state_tomo = sim_noisy_jakarta, sim_noisy_jakarta
quadratic_loss=True

optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                        backend_opt, backend_state_tomo, quadratic_loss)
# Out:
# ################################################################################
#
# Starting optimization!
#
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.1
# ==================================================
#
# Iter 1 done!
# Loss value: 0.23108210409999996
# Current parameters: [0.    1.642 0.258 1.242] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.1565864041
# Current parameters: [0.    1.295 0.    1.846] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.08682451560000001
# Current parameters: [0.    1.494 0.    1.647] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.08616573160000002
# Current parameters: [2.394e-16 1.508e+00 3.256e-17 1.634e+00] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.08512389760000001
# Current parameters: [0.000e+00 1.556e+00 5.991e-17 1.585e+00] (sum to 3.14)
#
# Iter 6 done!
# Loss value: 0.0850830561
# Current parameters: [0.000e+00 1.575e+00 9.814e-17 1.566e+00] (sum to 3.14)
#
# Iter 7 done!
# Loss value: 0.08507722240000003
# Current parameters: [0.000e+00 1.572e+00 1.395e-16 1.570e+00] (sum to 3.14)
#
# Iter 8 done!
# Loss value: 0.08507722240000003
# Current parameters: [0.000e+00 1.572e+00 1.361e-16 1.570e+00] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.08507722240000003
#             Iterations: 8
#             Function evaluations: 51
#             Gradient evaluations: 8
#
# Total time of optimization: 00:00:45
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.01
# ==================================================
#
# Iter 1 done!
# Loss value: 0.27719172010000004
# Current parameters: [0.009 1.652 0.241 1.24 ] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.10423212249999998
# Current parameters: [0.    1.388 0.    1.753] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.19766915999999998
# Current parameters: [8.231e-13 1.420e+00 5.354e-12 1.722e+00] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.08522896359999999
# Current parameters: [0.    1.545 0.    1.596] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.1814589604
# Current parameters: [1.356e-12 1.554e+00 8.900e-12 1.588e+00] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.08522896359999999
#             Iterations: 5
#             Function evaluations: 38
#             Gradient evaluations: 5
#
# Total time of optimization: 00:00:32
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.001
# ==================================================
#
# Iter 1 done!
# Loss value: 0.35559754239999997
# Current parameters: [2.220e-16 1.603e+00 3.715e-01 1.167e+00] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.0940771584
# Current parameters: [9.837e-14 1.429e+00 9.526e-14 1.712e+00] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.08983807290000004
# Current parameters: [0.    1.456 0.    1.686] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.18552833289999995
# Current parameters: [4.367e-11 1.485e+00 1.093e-09 1.657e+00] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.1817146384
# Current parameters: [6.382e-11 1.600e+00 1.565e-09 1.541e+00] (sum to 3.14)
#
# Iter 6 done!
# Loss value: 0.08978412960000001
# Current parameters: [0.    1.456 0.    1.685] (sum to 3.14)
#
# Iter 7 done!
# Loss value: 0.0896703025
# Current parameters: [0.    1.457 0.    1.684] (sum to 3.14)
#
# Iter 8 done!
# Loss value: 0.18816508840000004
# Current parameters: [8.712e-11 1.465e+00 2.169e-09 1.677e+00] (sum to 3.14)
#
# Iter 9 done!
# Loss value: 0.18469365760000003
# Current parameters: [2.353e-11 1.495e+00 5.968e-10 1.646e+00] (sum to 3.14)
#
# Iter 10 done!
# Loss value: 0.18469365760000003
# Current parameters: [8.695e-11 1.647e+00 2.188e-09 1.495e+00] (sum to 3.14)
#
# Iter 11 done!
# Loss value: 0.9370820808999999
# Current parameters: [7.884e-11 2.403e+00 1.956e-09 7.384e-01] (sum to 3.14)
#
# Iter 12 done!
# Loss value: 0.08507722240000003
# Current parameters: [3.329e-10 3.142e+00 8.288e-09 0.000e+00] (sum to 3.14)
#
# Iter 13 done!
# Loss value: 0.08507722240000003
# Current parameters: [8.389e-11 3.142e+00 2.113e-09 0.000e+00] (sum to 3.14)
#
# Iter 14 done!
# Loss value: 0.08507722240000003
# Current parameters: [0.000e+00 3.142e+00 0.000e+00 2.987e-09] (sum to 3.14)
#
# Iter 15 done!
# Loss value: 0.1814845201
# Current parameters: [1.070e-10 1.552e+00 2.639e-09 1.589e+00] (sum to 3.14)
#
# Iter 16 done!
# Loss value: 0.1814589604
# Current parameters: [2.502e-11 1.588e+00 6.196e-10 1.554e+00] (sum to 3.14)
#
# Iter 17 done!
# Loss value: 0.21251178010000002
# Current parameters: [1.114e-10 1.764e+00 2.732e-09 1.378e+00] (sum to 3.14)
#
# Iter 18 done!
# Loss value: 0.5506530435999999
# Current parameters: [0.    2.645 0.    0.497] (sum to 3.14)
#
# Iter 19 done!
# Loss value: 0.1814589604
# Current parameters: [2.785e-11 1.587e+00 6.949e-10 1.554e+00] (sum to 3.14)
#
# Iter 20 done!
# Loss value: 0.08882188090000001
# Current parameters: [0.    1.675 0.    1.466] (sum to 3.14)
#
# Iter 21 done!
# Loss value: 0.6722360099999999
# Current parameters: [0.    2.119 0.    1.023] (sum to 3.14)
#
# Iter 22 done!
# Loss value: 0.08507722240000003
# Current parameters: [1.228e-11 3.142e+00 2.990e-10 0.000e+00] (sum to 3.14)
#
# Iter 23 done!
# Loss value: 0.08507722240000003
# Current parameters: [0.000e+00 3.142e+00 0.000e+00 2.791e-08] (sum to 3.14)
#
# Iter 24 done!
# Loss value: 0.08507722240000003
# Current parameters: [8.787e-12 3.142e+00 2.318e-10 0.000e+00] (sum to 3.14)
#
# Iter 25 done!
# Loss value: 0.08507722240000003
# Current parameters: [0.000e+00 3.142e+00 0.000e+00 8.697e-09] (sum to 3.14)
#
# Iter 26 done!
# Loss value: 0.08507722240000003
# Current parameters: [0.    1.571 0.    1.571] (sum to 3.14)
#
# Iter 27 done!
# Loss value: 0.08507722240000003
# Current parameters: [1.535e-15 1.571e+00 3.825e-14 1.571e+00] (sum to 3.14)
#
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.08507722240000003
#             Iterations: 31
#             Function evaluations: 315
#             Gradient evaluations: 27
#
# Total time of optimization: 00:04:16
# Optimization results:
#   optimizer    eps                                       final_params  \
# 0     slsqp  0.100  [0.0, 1.5718654335934839, 1.3948718372766983e-...
# 2     slsqp  0.001  [1.5354173990627093e-15, 1.57061405389031, 3.8...
# 1     slsqp  0.010  [5.295477895403405e-17, 1.5452813250331499, 3....
#
#    final_loss
# 0    0.085077
# 2    0.085077
# 1    0.085229
# Best parameters (sum to 3.14):	[0.000e+00 1.572e+00 1.395e-16 1.570e+00]
# Best parameters (sum to 1):	[0.000e+00 5.003e-01 4.440e-17 4.997e-01]
# ################################################################################
# Single trotterization step:
# ################################################################################
#
# All steps + measurements of state tomography:
# ################################################################################
#
# 1/8 - Job ID 3212edc8-18cc-4bcb-8164-f21afd5eb824
# 2/8 - Job ID 89a28ccb-9df5-42a8-8884-c4f318b06a7d
# 3/8 - Job ID 42668661-0b0f-4e05-b420-3ac4205e07db
# 4/8 - Job ID 89e80a1e-70d7-4bdb-93e8-90507cf33f69
# 5/8 - Job ID 5383b093-7ffc-4127-8d44-f6db101a23ba
# 6/8 - Job ID 835f58ba-1edb-4783-a26a-3d07869debdb
# 7/8 - Job ID d09ac1a6-1793-46ae-bcd2-5684d67240d5
# 8/8 - Job ID 931bf8a0-ac40-47fd-854e-b7363066d6d1
#
# ################################################################################
#
# Final results - order: 1 - strotter steps: 4
#
# State tomography fidelity = 0.7086 ± 0.0014
#
# ################################################################################
#
# Starting simulation for times from 0 to pi!
# Simulation ended!
# Total time of simulation: 00:01:25

# %% [markdown]
# ### First order, 4 steps, variable time, params_bounds_min=0.1

# %%
order, trotter_steps = 1, 4
uniform_times = False
params_bounds_min = 0.1
backend_opt, backend_state_tomo = sim_noisy_jakarta, sim_noisy_jakarta
quadratic_loss=True

optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                        backend_opt, backend_state_tomo, quadratic_loss)
# Out:
# ################################################################################
#
# Starting optimization!
#
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.1
# ==================================================
#
# Iter 1 done!
# Loss value: 0.37865562250000007
# Current parameters: [0.1   1.447 0.357 1.237] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.22740499690000002
# Current parameters: [0.1   1.286 0.1   1.655] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.19135375360000004
# Current parameters: [0.1   1.469 0.1   1.472] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.1910039616
# Current parameters: [0.1   1.448 0.1   1.494] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.19123129000000003
# Current parameters: [0.1   1.437 0.1   1.504] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.1910039616
#             Iterations: 5
#             Function evaluations: 36
#             Gradient evaluations: 5
#
# Total time of optimization: 00:00:30
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.01
# ==================================================
#
# Iter 1 done!
# Loss value: 0.48573930249999997
# Current parameters: [0.1   1.402 0.424 1.216] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.19272099999999995
# Current parameters: [0.1   1.41  0.1   1.531] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.1910039616
# Current parameters: [0.1   1.448 0.1   1.493] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.1910039616
# Current parameters: [0.1   1.45  0.1   1.492] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.1910039616
#             Iterations: 4
#             Function evaluations: 31
#             Gradient evaluations: 4
#
# Total time of optimization: 00:00:26
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.001
# ==================================================
#
# Iter 1 done!
# Loss value: 0.6370274596
# Current parameters: [0.1   1.387 0.498 1.156] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.19325695209999996
# Current parameters: [0.1   1.404 0.1   1.537] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.1910039616
# Current parameters: [0.1   1.448 0.1   1.494] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.1910039616
# Current parameters: [0.1   1.457 0.1   1.485] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.19098648039999996
# Current parameters: [0.1   1.452 0.1   1.489] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.19098648039999996
#             Iterations: 5
#             Function evaluations: 26
#             Gradient evaluations: 5
#
# Total time of optimization: 00:00:23
# Optimization results:
#   optimizer    eps                                       final_params  \
# 2     slsqp  0.001  [0.10000000000000003, 1.4522965742472167, 0.1,...
# 0     slsqp  0.100  [0.1, 1.4475647251545265, 0.10000000000000002,...
# 1     slsqp  0.010  [0.10000000000000005, 1.4483286512654285, 0.1,...
#
#    final_loss
# 2    0.190986
# 0    0.191004
# 1    0.191004
# Best parameters (sum to 3.14):	[0.1   1.452 0.1   1.489]
# Best parameters (sum to 1):	[0.032 0.462 0.032 0.474]
# ################################################################################
# Single trotterization step:
# ################################################################################
#
# All steps + measurements of state tomography:
# ################################################################################
#
# 1/8 - Job ID 9a8881de-641d-4b14-b815-d138585dda71
# 2/8 - Job ID 4cd067e1-7c92-4e5f-a50d-40a8e7c3e762
# 3/8 - Job ID 580713af-0a5e-417c-a156-366b8ac82a6c
# 4/8 - Job ID d97104c8-0d3e-465e-abfc-2334a3d739b8
# 5/8 - Job ID 9e00952b-9f35-4355-915d-537c14d2bbe8
# 6/8 - Job ID 71e05350-e4a4-429c-92d1-36b9fb6252a4
# 7/8 - Job ID 540ad750-5a65-4832-9b82-12c83cf08ee7
# 8/8 - Job ID 42e05273-c0af-40ac-a3a2-3d2eab2fe8f4
#
# ################################################################################
#
# Final results - order: 1 - strotter steps: 4
#
# State tomography fidelity = 0.5619 ± 0.0019
#
# ################################################################################
#
# Starting simulation for times from 0 to pi!
# Simulation ended!
# Total time of simulation: 00:01:24

# %% [markdown]
# ### First order, 4 steps, variable time, params_bounds_min=0.5

# %%
order, trotter_steps = 1, 4
uniform_times = False
params_bounds_min = 0.5
backend_opt, backend_state_tomo = sim_noisy_jakarta, sim_noisy_jakarta
quadratic_loss=True

optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                        backend_opt, backend_state_tomo, quadratic_loss)
# Out:
# ################################################################################
#
# Starting optimization!
#
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.1
# ==================================================
#
# Iter 1 done!
# Loss value: 0.8676363609000001
# Current parameters: [0.5   1.169 0.972 0.5  ] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.7774477929
# Current parameters: [0.5   1.036 1.105 0.5  ] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.8222681041
# Current parameters: [0.607 0.5   1.535 0.5  ] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.7331469376
# Current parameters: [0.549 0.889 1.194 0.51 ] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.7242350404
# Current parameters: [0.599 0.78  1.176 0.587] (sum to 3.14)
#
# Iter 6 done!
# Loss value: 0.73564929
# Current parameters: [0.684 0.5   1.141 0.817] (sum to 3.14)
#
# Iter 7 done!
# Loss value: 0.6826890625
# Current parameters: [0.576 0.629 1.096 0.841] (sum to 3.14)
#
# Iter 8 done!
# Loss value: 0.6633450916
# Current parameters: [0.5   0.5   1.021 1.12 ] (sum to 3.14)
#
# Iter 9 done!
# Loss value: 0.6177331215999999
# Current parameters: [0.5   0.501 1.079 1.062] (sum to 3.14)
#
# Iter 10 done!
# Loss value: 0.59459521
# Current parameters: [0.5   0.5   1.157 0.984] (sum to 3.14)
#
# Iter 11 done!
# Loss value: 0.5958141721
# Current parameters: [0.5   0.5   1.135 1.006] (sum to 3.14)
#
# Iter 12 done!
# Loss value: 0.5957061123999999
# Current parameters: [0.5   0.5   1.136 1.006] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5944564201
#             Iterations: 12
#             Function evaluations: 74
#             Gradient evaluations: 12
#
# Total time of optimization: 00:01:05
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.01
# ==================================================
#
# Iter 1 done!
# Loss value: 0.8939513400999999
# Current parameters: [0.5   1.186 0.805 0.651] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.8258265624999999
# Current parameters: [0.54  1.264 0.566 0.771] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.8024038928999999
# Current parameters: [0.686 1.199 0.5   0.756] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.5936856601
# Current parameters: [1.171 0.971 0.5   0.5  ] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.5929308004
# Current parameters: [1.197 0.944 0.5   0.5  ] (sum to 3.14)
#
# Iter 6 done!
# Loss value: 0.5928538009000001
# Current parameters: [1.189 0.952 0.5   0.5  ] (sum to 3.14)
#
# Iter 7 done!
# Loss value: 0.5928846000999999
# Current parameters: [1.187 0.955 0.5   0.5  ] (sum to 3.14)
#
# Iter 8 done!
# Loss value: 0.5931772324
# Current parameters: [1.179 0.963 0.5   0.5  ] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5928384016
#             Iterations: 8
#             Function evaluations: 54
#             Gradient evaluations: 8
#
# Total time of optimization: 00:00:49
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.001
# ==================================================
#
# Iter 1 done!
# Loss value: 0.9067419729
# Current parameters: [0.5   1.193 0.862 0.586] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.9013223844
# Current parameters: [0.547 1.2   0.835 0.56 ] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.8263173603999999
# Current parameters: [0.828 1.175 0.639 0.5  ] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.6780369649
# Current parameters: [0.966 1.176 0.5   0.5  ] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.6187710244
# Current parameters: [1.08  1.062 0.5   0.5  ] (sum to 3.14)
#
# Iter 6 done!
# Loss value: 0.7622686863999999
# Current parameters: [1.475 0.667 0.5   0.5  ] (sum to 3.14)
#
# Iter 7 done!
# Loss value: 0.5929770025000001
# Current parameters: [1.198 0.944 0.5   0.5  ] (sum to 3.14)
#
# Iter 8 done!
# Loss value: 0.5928384016
# Current parameters: [1.194 0.948 0.5   0.5  ] (sum to 3.14)
#
# Iter 9 done!
# Loss value: 0.5933312784
# Current parameters: [1.206 0.935 0.5   0.5  ] (sum to 3.14)
#
# Iter 10 done!
# Loss value: 0.6075267136
# Current parameters: [1.27  0.872 0.5   0.5  ] (sum to 3.14)
#
# Iter 11 done!
# Loss value: 0.8448183396
# Current parameters: [1.587 0.554 0.5   0.5  ] (sum to 3.14)
#
# Iter 12 done!
# Loss value: 0.5927922049
# Current parameters: [1.191 0.951 0.5   0.5  ] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5927922049
#             Iterations: 12
#             Function evaluations: 103
#             Gradient evaluations: 12
#
# Total time of optimization: 00:01:53
# Optimization results:
#   optimizer    eps                                       final_params  \
# 2     slsqp  0.001  [1.190636687731103, 0.9509559658723179, 0.5, 0.5]
# 1     slsqp  0.010  [1.1890422562063456, 0.9525503973838976, 0.500...
# 0     slsqp  0.100  [0.5, 0.5, 1.149107427683647, 0.9924852259061463]
#
#    final_loss
# 2    0.592792
# 1    0.592838
# 0    0.594456
# Best parameters (sum to 3.14):	[1.191 0.951 0.5   0.5  ]
# Best parameters (sum to 1):	[0.379 0.303 0.159 0.159]
# ################################################################################
# Single trotterization step:
# ################################################################################
#
# All steps + measurements of state tomography:
# ################################################################################
#
# 1/8 - Job ID 72fca9c5-8c11-4228-875c-f6dee5efce71
# 2/8 - Job ID 74a6d372-0ff1-4ac2-a582-860a2e78868c
# 3/8 - Job ID 4f77b517-d393-4d50-a563-507519a901f1
# 4/8 - Job ID ecd62c23-2c26-4353-804d-22ac46386f3c
# 5/8 - Job ID 55ed5b5b-85d5-4a53-a107-fb957e564530
# 6/8 - Job ID ea2cebfc-ac8a-4c0e-adeb-cbcf6fbc54fa
# 7/8 - Job ID 8d181743-73c9-48d4-b02d-cbd6adc6a094
# 8/8 - Job ID c625af21-b108-4f29-91a4-d5a67c266ff2
#
# ################################################################################
#
# Final results - order: 1 - strotter steps: 4
#
# State tomography fidelity = 0.2312 ± 0.0012
#
# ################################################################################
#
# Starting simulation for times from 0 to pi!
# Simulation ended!
# Total time of simulation: 00:01:37

# %% [markdown]
# ### First order, 4 steps, variable time, params_bounds_min=-pi (allowing negative times)

# %%
order, trotter_steps = 1, 4
uniform_times = False
params_bounds_min = -np.pi
backend_opt, backend_state_tomo = sim_noisy_jakarta, sim_noisy_jakarta
quadratic_loss=True

optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                        backend_opt, backend_state_tomo, quadratic_loss)
# Out:
# ################################################################################
#
# Starting optimization!
#
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.1
# ==================================================
#
# Iter 1 done!
# Loss value: 0.6271689636
# Current parameters: [-1.332  1.954  0.975  1.545] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.6954392449000001
# Current parameters: [-0.699  2.022  1.523  0.296] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.8524274929000001
# Current parameters: [-0.035  0.086  2.185  0.905] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.7208689216
# Current parameters: [-0.145  0.71   2.113  0.463] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.42852734439999995
# Current parameters: [-0.277  1.15   1.885  0.383] (sum to 3.14)
#
# Iter 6 done!
# Loss value: 0.35895675689999995
# Current parameters: [ 0.229  1.802  1.487 -0.377] (sum to 3.14)
#
# Iter 7 done!
# Loss value: 0.28241784490000005
# Current parameters: [-0.15   1.291  1.776  0.224] (sum to 3.14)
#
# Iter 8 done!
# Loss value: 0.18231192040000002
# Current parameters: [ 0.025  1.523  1.634 -0.04 ] (sum to 3.14)
#
# Iter 9 done!
# Loss value: 0.18176579560000006
# Current parameters: [ 0.025  1.523  1.61  -0.016] (sum to 3.14)
#
# Iter 10 done!
# Loss value: 0.18161234559999997
# Current parameters: [ 0.021  1.528  1.597 -0.004] (sum to 3.14)
#
# Iter 11 done!
# Loss value: 0.18147600000000003
# Current parameters: [0.014 1.538 1.584 0.005] (sum to 3.14)
#
# Iter 12 done!
# Loss value: 0.18140784639999996
# Current parameters: [0.005 1.558 1.567 0.012] (sum to 3.14)
#
# Iter 13 done!
# Loss value: 0.18136525689999997
# Current parameters: [1.512e-03 1.567e+00 1.564e+00 9.254e-03] (sum to 3.14)
#
# Iter 14 done!
# Loss value: 0.1813567396
# Current parameters: [6.963e-04 1.570e+00 1.568e+00 3.311e-03] (sum to 3.14)
#
# Iter 15 done!
# Loss value: 0.1813567396
# Current parameters: [5.390e-04 1.570e+00 1.570e+00 9.806e-04] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.1813567396
#             Iterations: 15
#             Function evaluations: 91
#             Gradient evaluations: 15
#
# Total time of optimization: 00:01:20
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.01
# ==================================================
#
# Iter 1 done!
# Loss value: 0.6739260648999998
# Current parameters: [-1.164  1.829  0.984  1.492] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.5375382489
# Current parameters: [-0.658  1.824  1.663  0.313] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.2666276495999999
# Current parameters: [-0.153  1.35   1.684  0.261] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.19760692089999998
# Current parameters: [0.06  1.386 1.577 0.119] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.1817146384
# Current parameters: [-0.005  1.549  1.566  0.032] (sum to 3.14)
#
# Iter 6 done!
# Loss value: 0.1814589604
# Current parameters: [0.003 1.559 1.56  0.021] (sum to 3.14)
#
# Iter 7 done!
# Loss value: 0.18138229209999998
# Current parameters: [0.003 1.571 1.557 0.011] (sum to 3.14)
#
# Iter 8 done!
# Loss value: 0.1813567396
# Current parameters: [1.376e-03 1.574e+00 1.559e+00 7.397e-03] (sum to 3.14)
#
# Iter 9 done!
# Loss value: 0.1813567396
# Current parameters: [-8.155e-04  1.575e+00  1.563e+00  4.631e-03] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.1813567396
#             Iterations: 9
#             Function evaluations: 58
#             Gradient evaluations: 9
#
# Total time of optimization: 00:00:50
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.001
# ==================================================
#
# Iter 1 done!
# Loss value: 0.7285134609
# Current parameters: [-1.17   1.695  0.958  1.658] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.7248989881
# Current parameters: [-0.768  2.076  1.605  0.229] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.7026295329000001
# Current parameters: [-0.378  0.961  2.211  0.348] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.6974087121
# Current parameters: [0.24  0.942 1.759 0.2  ] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.25620806890000003
# Current parameters: [-0.056  1.276  1.736  0.186] (sum to 3.14)
#
# Iter 6 done!
# Loss value: 0.18978220960000003
# Current parameters: [0.062 1.639 1.419 0.021] (sum to 3.14)
#
# Iter 7 done!
# Loss value: 0.18252547289999999
# Current parameters: [0.018 1.582 1.494 0.047] (sum to 3.14)
#
# Iter 8 done!
# Loss value: 0.18193637160000004
# Current parameters: [0.011 1.567 1.52  0.043] (sum to 3.14)
#
# Iter 9 done!
# Loss value: 0.18193637160000004
# Current parameters: [0.011 1.567 1.52  0.043] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.18193637160000004
#             Iterations: 9
#             Function evaluations: 49
#             Gradient evaluations: 9
#
# Total time of optimization: 00:00:43
# Optimization results:
#   optimizer    eps                                       final_params  \
# 0     slsqp  0.100  [0.0006961686449667735, 1.5698518040478804, 1....
# 1     slsqp  0.010  [0.0013739475706671467, 1.57413402341906, 1.55...
# 2     slsqp  0.001  [0.01145989154075254, 1.566874601270628, 1.519...
#
#    final_loss
# 0    0.181357
# 1    0.181357
# 2    0.181936
# Best parameters (sum to 3.14):	[6.962e-04 1.570e+00 1.568e+00 3.309e-03]
# Best parameters (sum to 1):	[2.216e-04 4.997e-01 4.990e-01 1.053e-03]
# ################################################################################
# Single trotterization step:
# ################################################################################
#
# All steps + measurements of state tomography:
# ################################################################################
#
# 1/8 - Job ID 82190115-6eab-4b5f-85c5-7f949e5625c7
# 2/8 - Job ID b2d3fab3-fd3e-49e6-b2c5-23d6680b7b3f
# 3/8 - Job ID 7d680e3e-bd7a-4d13-a9ee-f0838454ebed
# 4/8 - Job ID 4cc052c8-e8c1-4893-82c6-08c67b4a28a8
# 5/8 - Job ID fafe3ba4-6336-4427-9216-eb6b4bf0aa08
# 6/8 - Job ID 77625afd-874e-4538-9d82-fbab89b503bf
# 7/8 - Job ID 46808717-2ccb-4d16-87a0-bc80fb1ea44f
# 8/8 - Job ID 17431cdc-f8f9-4675-b29a-ef17766d5660
#
# ################################################################################
#
# Final results - order: 1 - strotter steps: 4
#
# State tomography fidelity = 0.5738 ± 0.0014
#
# ################################################################################
#
# Starting simulation for times from 0 to pi!
# Simulation ended!
# Total time of simulation: 00:01:25

# %% [markdown]
# ___________

# %% [markdown]
# ### First order, 5 steps, variable time, params_bounds_min=0

# %%
order, trotter_steps = 1, 5
uniform_times = False
params_bounds_min = 0
backend_opt, backend_state_tomo = sim_noisy_jakarta, sim_noisy_jakarta
quadratic_loss=True

optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                        backend_opt, backend_state_tomo, quadratic_loss)
# Out:
# ################################################################################
#
# Starting optimization!
#
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.1
# ==================================================
#
# Iter 1 done!
# Loss value: 0.9458535025
# Current parameters: [0.000e+00 1.892e+00 7.640e-01 4.854e-01 6.106e-16] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.8721692099999999
# Current parameters: [0.    2.006 0.629 0.331 0.175] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.9287369641
# Current parameters: [4.965e-17 2.446e+00 6.661e-16 4.441e-16 6.960e-01] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.4231242303999999
# Current parameters: [0.    2.699 0.    0.    0.442] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.08563816960000001
# Current parameters: [0.    3.096 0.    0.    0.046] (sum to 3.14)
#
# Iter 6 done!
# Loss value: 0.013128576400000003
# Current parameters: [1.427e-15 3.142e+00 1.202e-14 6.463e-15 0.000e+00] (sum to 3.14)
#
# Iter 7 done!
# Loss value: 0.013128576400000003
# Current parameters: [1.427e-15 3.142e+00 1.202e-14 6.463e-15 0.000e+00] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.013128576400000003
#             Iterations: 7
#             Function evaluations: 43
#             Gradient evaluations: 7
#
# Total time of optimization: 00:00:46
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.01
# ==================================================
#
# Iter 1 done!
# Loss value: 0.9346055625
# Current parameters: [2.220e-16 1.955e+00 7.467e-01 4.396e-01 4.996e-16] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.8202562624
# Current parameters: [0.    1.903 0.263 0.146 0.83 ] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.86378436
# Current parameters: [0.000e+00 9.276e-01 0.000e+00 1.110e-16 2.214e+00] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.18157825440000006
# Current parameters: [0.000e+00 1.550e+00 3.520e-04 4.938e-03 1.586e+00] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.18137377440000002
# Current parameters: [0.    1.561 0.005 0.002 1.574] (sum to 3.14)
#
# Iter 6 done!
# Loss value: 0.13264163999999998
# Current parameters: [1.289e-14 1.568e+00 7.079e-03 8.296e-15 1.566e+00] (sum to 3.14)
#
# Iter 7 done!
# Loss value: 0.13264163999999998
# Current parameters: [0.    1.569 0.006 0.    1.567] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.13264163999999998
#             Iterations: 7
#             Function evaluations: 54
#             Gradient evaluations: 7
#
# Total time of optimization: 00:00:48
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.001
# ==================================================
#
# Iter 1 done!
# Loss value: 0.9052190449
# Current parameters: [0.    2.015 0.681 0.445 0.   ] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.8307228736000001
# Current parameters: [0.    2.121 0.048 0.056 0.918] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.5250596520999999
# Current parameters: [9.917e-01 1.779e+00 4.441e-16 1.959e-02 3.514e-01] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.5337471364
# Current parameters: [1.02  1.522 0.    0.235 0.364] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.4962779808999999
# Current parameters: [1.048 1.635 0.    0.087 0.372] (sum to 3.14)
#
# Iter 6 done!
# Loss value: 0.48958008999999997
# Current parameters: [1.206e+00 1.511e+00 1.588e-09 2.604e-09 4.251e-01] (sum to 3.14)
#
# Iter 7 done!
# Loss value: 0.43876051210000006
# Current parameters: [1.237e+00 1.470e+00 1.099e-04 0.000e+00 4.347e-01] (sum to 3.14)
#
# Iter 8 done!
# Loss value: 0.013128576400000003
# Current parameters: [3.142 0.    3.142 0.    3.142] (sum to 9.42)
#
# Iter 9 done!
# Loss value: 0.3829753225
# Current parameters: [1.239e+00 1.470e+00 0.000e+00 3.361e-18 4.327e-01] (sum to 3.14)
#
# Iter 10 done!
# Loss value: 0.4342019236000001
# Current parameters: [1.240e+00 1.470e+00 0.000e+00 2.082e-11 4.319e-01] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.3829753225
#             Iterations: 10
#             Function evaluations: 86
#             Gradient evaluations: 10
#
# Total time of optimization: 00:01:20
# Optimization results:
#   optimizer    eps                                       final_params  \
# 0     slsqp  0.100  [1.4274571381171786e-15, 3.1415926535897785, 1...
# 1     slsqp  0.010  [1.2881070394418655e-14, 1.5681296661835387, 0...
# 2     slsqp  0.001  [1.239147311110013, 1.469753926872719, 0.0, 8....
#
#    final_loss
# 0    0.013129
# 1    0.132642
# 2    0.382975
# Best parameters (sum to 3.14):	[1.427e-15 3.142e+00 1.202e-14 6.463e-15 0.000e+00]
# Best parameters (sum to 1):	[4.544e-16 1.000e+00 3.826e-15 2.057e-15 0.000e+00]
# ################################################################################
# Single trotterization step:
# ################################################################################
#
# All steps + measurements of state tomography:
# ################################################################################
#
# 1/8 - Job ID 567e1dea-ad3b-49c5-881e-632b18042588
# 2/8 - Job ID 61bc03ed-2e1b-4396-af77-b9f04380533b
# 3/8 - Job ID 526b1b81-46fc-4af1-aee2-2c087a436bdc
# 4/8 - Job ID 1dfc1cc1-ce7c-4dcf-8143-05a33231352f
# 5/8 - Job ID 1cd701be-ae9d-4dc4-9958-396cd972b468
# 6/8 - Job ID af6b9111-11e1-4b32-ad10-821c2ffba628
# 7/8 - Job ID 5bee4613-a7e6-4eeb-b67e-f1991717f67d
# 8/8 - Job ID 65fb765f-e3e9-4527-870f-5ac605f5fa8f
#
# ################################################################################
#
# Final results - order: 1 - strotter steps: 5
#
# State tomography fidelity = 0.8861 ± 0.0015
#
# ################################################################################
#
# Starting simulation for times from 0 to pi!
# Simulation ended!
# Total time of simulation: 00:01:35

# %% [markdown]
# ### First order, 5 steps, variable time, params_bounds_min=0.1

# %%
order, trotter_steps = 1, 5
uniform_times = False
params_bounds_min = 0.1
backend_opt, backend_state_tomo = sim_noisy_jakarta, sim_noisy_jakarta
quadratic_loss=True

optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                        backend_opt, backend_state_tomo, quadratic_loss)
# Out:
# ################################################################################
#
# Starting optimization!
#
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.1
# ==================================================
#
# Iter 1 done!
# Loss value: 0.4836785209
# Current parameters: [0.1   1.494 1.109 0.339 0.1  ] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.35378704
# Current parameters: [0.1   1.182 1.616 0.1   0.144] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.2699841600000001
# Current parameters: [0.1   1.332 1.509 0.1   0.1  ] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.25956987039999996
# Current parameters: [0.1   1.419 1.423 0.1   0.1  ] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.2596106304
# Current parameters: [0.1   1.436 1.406 0.1   0.1  ] (sum to 3.14)
#
# Iter 6 done!
# Loss value: 0.2596004401
# Current parameters: [0.1   1.436 1.406 0.1   0.1  ] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.2594577969
#             Iterations: 6
#             Function evaluations: 48
#             Gradient evaluations: 6
#
# Total time of optimization: 00:00:43
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.01
# ==================================================
#
# Iter 1 done!
# Loss value: 0.6607251224999999
# Current parameters: [0.1   1.593 0.978 0.371 0.1  ] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.33302132640000004
# Current parameters: [0.1   1.198 1.641 0.1   0.103] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.26461764810000005
# Current parameters: [0.1   1.36  1.482 0.1   0.1  ] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.25967177639999994
# Current parameters: [0.1   1.414 1.427 0.1   0.1  ] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.2594985480999999
# Current parameters: [0.1   1.422 1.419 0.1   0.1  ] (sum to 3.14)
#
# Iter 6 done!
# Loss value: 0.2607736356
# Current parameters: [0.1   1.458 1.383 0.1   0.1  ] (sum to 3.14)
#
# Iter 7 done!
# Loss value: 0.25946798439999996
# Current parameters: [0.1   1.428 1.414 0.1   0.1  ] (sum to 3.14)
#
# Iter 8 done!
# Loss value: 0.25946798439999996
# Current parameters: [0.1   1.428 1.414 0.1   0.1  ] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.25946798439999996
#             Iterations: 8
#             Function evaluations: 49
#             Gradient evaluations: 8
#
# Total time of optimization: 00:00:45
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.001
# ==================================================
#
# Iter 1 done!
# Loss value: 0.7346889796
# Current parameters: [0.1   1.565 0.936 0.44  0.1  ] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.48413764
# Current parameters: [0.1   1.142 1.482 0.1   0.317] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.2658846096
# Current parameters: [0.1   1.352 1.49  0.1   0.1  ] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.25969216000000006
# Current parameters: [0.1   1.439 1.402 0.1   0.1  ] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.2595494916
# Current parameters: [0.1   1.432 1.41  0.1   0.1  ] (sum to 3.14)
#
# Iter 6 done!
# Loss value: 0.25946798439999996
# Current parameters: [0.1   1.425 1.417 0.1   0.1  ] (sum to 3.14)
#
# Iter 7 done!
# Loss value: 0.25946798439999996
# Current parameters: [0.1   1.425 1.417 0.1   0.1  ] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.25946798439999996
#             Iterations: 7
#             Function evaluations: 42
#             Gradient evaluations: 7
#
# Total time of optimization: 00:00:38
# Optimization results:
#   optimizer    eps                                       final_params  \
# 0     slsqp  0.100  [0.1, 1.42655849378941, 1.415034159800383, 0.1...
# 1     slsqp  0.010  [0.10000000000000002, 1.427597245117439, 1.413...
# 2     slsqp  0.001  [0.1, 1.42472954530651, 1.4168631082832828, 0....
#
#    final_loss
# 0    0.259458
# 1    0.259468
# 2    0.259468
# Best parameters (sum to 3.14):	[0.1   1.427 1.415 0.1   0.1  ]
# Best parameters (sum to 1):	[0.032 0.454 0.45  0.032 0.032]
# ################################################################################
# Single trotterization step:
# ################################################################################
#
# All steps + measurements of state tomography:
# ################################################################################
#
# 1/8 - Job ID 8880c03d-7d58-4cfc-b81d-e111e7d00c65
# 2/8 - Job ID facf1b45-5bf0-459c-8c22-174605ac1e08
# 3/8 - Job ID 206018f6-76cb-4da3-aaec-27b73268b54c
# 4/8 - Job ID 2749d1b4-5f9e-415a-b66f-d45cda57fcd5
# 5/8 - Job ID bd556566-20a7-4fe5-a7fc-c37eaf27f22a
# 6/8 - Job ID d9d4701f-2731-4f45-87bd-5fef39d282bf
# 7/8 - Job ID 447a2c31-3fb6-464a-93b0-47a20c979c31
# 8/8 - Job ID 8ae73243-9c61-4313-8b6c-acc0aca677e8
#
# ################################################################################
#
# Final results - order: 1 - strotter steps: 5
#
# State tomography fidelity = 0.4895 ± 0.0026
#
# ################################################################################
#
# Starting simulation for times from 0 to pi!
# Simulation ended!
# Total time of simulation: 00:01:29

# %% [markdown]
# ### First order, 5 steps, variable time, params_bounds_min=-pi (allowing negative times)

# %%
order, trotter_steps = 1, 5
uniform_times = False
params_bounds_min = -np.pi
backend_opt, backend_state_tomo = sim_noisy_jakarta, sim_noisy_jakarta
quadratic_loss=True

optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                        backend_opt, backend_state_tomo, quadratic_loss)
# Out:
# ################################################################################
#
# Starting optimization!
#
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.1
# ==================================================
#
# Iter 1 done!
# Loss value: 0.9121969081
# Current parameters: [-0.223  3.008  1.807  0.809 -2.259] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.7794594369000001
# Current parameters: [-0.377  2.877  1.987  1.066 -2.411] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.8243187264000001
# Current parameters: [-0.594  2.132  2.518  2.226 -3.142] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.8612396809
# Current parameters: [-0.706  1.637  2.211  3.142 -3.142] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.5652934596
# Current parameters: [-0.428  2.589  2.003  1.594 -2.617] (sum to 3.14)
#
# Iter 6 done!
# Loss value: 0.4867573824000001
# Current parameters: [-0.334  2.682  1.651  1.842 -2.7  ] (sum to 3.14)
#
# Iter 7 done!
# Loss value: 0.37494802890000006
# Current parameters: [-0.206  2.778  1.696  1.805 -2.931] (sum to 3.14)
#
# Iter 8 done!
# Loss value: 0.22982436000000003
# Current parameters: [-0.123  2.945  1.775  1.686 -3.142] (sum to 3.14)
#
# Iter 9 done!
# Loss value: 0.21369355289999997
# Current parameters: [-0.084  2.957  1.747  1.663 -3.142] (sum to 3.14)
#
# Iter 10 done!
# Loss value: 0.18702165159999995
# Current parameters: [ 0.005  3.017  1.665  1.596 -3.142] (sum to 3.14)
#
# Iter 11 done!
# Loss value: 0.18294439839999999
# Current parameters: [ 0.031  3.054  1.628  1.57  -3.142] (sum to 3.14)
#
# Iter 12 done!
# Loss value: 0.2325264841
# Current parameters: [ 0.061  3.142  1.555  1.526 -3.142] (sum to 3.14)
#
# Iter 13 done!
# Loss value: 0.13323230009999995
# Current parameters: [ 0.038  3.142  1.563  1.54  -3.142] (sum to 3.14)
#
# Iter 14 done!
# Loss value: 0.13291128489999995
# Current parameters: [ 0.027  3.142  1.566  1.548 -3.142] (sum to 3.14)
#
# Iter 15 done!
# Loss value: 0.13264163999999998
# Current parameters: [ 0.004  3.142  1.572  1.566 -3.142] (sum to 3.14)
#
# Iter 16 done!
# Loss value: 0.13264163999999998
# Current parameters: [ 3.783e-04  3.142e+00  1.573e+00  1.568e+00 -3.142e+00] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.13264163999999998
#             Iterations: 16
#             Function evaluations: 113
#             Gradient evaluations: 16
#
# Total time of optimization: 00:01:41
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.01
# ==================================================
#
# Iter 1 done!
# Loss value: 0.8933274256
# Current parameters: [-0.156  2.969  1.729  0.914 -2.315] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.7579095364
# Current parameters: [-0.25   2.802  1.75   1.289 -2.45 ] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.7126061056
# Current parameters: [-0.354  2.367  1.867  2.403 -3.142] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.4813168129
# Current parameters: [-0.278  2.799  1.694  1.632 -2.705] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.41240799610000006
# Current parameters: [-0.243  2.697  1.75   1.758 -2.822] (sum to 3.14)
#
# Iter 6 done!
# Loss value: 0.25547970249999996
# Current parameters: [-0.096  2.893  1.672  1.814 -3.142] (sum to 3.14)
#
# Iter 7 done!
# Loss value: 0.20132271610000002
# Current parameters: [-0.038  2.967  1.717  1.637 -3.142] (sum to 3.14)
#
# Iter 8 done!
# Loss value: 0.18772289290000005
# Current parameters: [ 0.031  3.     1.665  1.586 -3.142] (sum to 3.14)
#
# Iter 9 done!
# Loss value: 0.2328352009
# Current parameters: [ 0.058  3.038  1.631  1.557 -3.142] (sum to 3.14)
#
# Iter 10 done!
# Loss value: 0.18326961000000003
# Current parameters: [ 0.054  3.07   1.628  1.532 -3.142] (sum to 3.14)
#
# Iter 11 done!
# Loss value: 0.23132252160000005
# Current parameters: [ 0.041  3.08   1.621  1.541 -3.142] (sum to 3.14)
#
# Iter 12 done!
# Loss value: 0.23127442809999996
# Current parameters: [ 0.052  3.075  1.6    1.556 -3.142] (sum to 3.14)
#
# Iter 13 done!
# Loss value: 0.18836468010000001
# Current parameters: [ 0.046  3.13   1.435  1.672 -3.142] (sum to 3.14)
#
# Iter 14 done!
# Loss value: 0.23092830250000004
# Current parameters: [ 0.05   3.09   1.567  1.577 -3.142] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.18205582239999996
#             Iterations: 14
#             Function evaluations: 102
#             Gradient evaluations: 14
#
# Total time of optimization: 00:01:31
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.001
# ==================================================
#
# Iter 1 done!
# Loss value: 0.9257133796
# Current parameters: [-0.038  2.919  1.681  0.87  -2.29 ] (sum to 3.14)
#
# Iter 2 done!
# Loss value: 0.8483331025
# Current parameters: [-0.067  2.74   1.698  1.111 -2.341] (sum to 3.14)
#
# Iter 3 done!
# Loss value: 0.7595994025000001
# Current parameters: [-0.337  2.772  1.779  1.361 -2.432] (sum to 3.14)
#
# Iter 4 done!
# Loss value: 0.9248861240999999
# Current parameters: [-1.508  2.748  2.396  2.648 -3.142] (sum to 3.14)
#
# Iter 5 done!
# Loss value: 0.5704931961
# Current parameters: [-0.481  2.832  1.799  1.66  -2.668] (sum to 3.14)
#
# Iter 6 done!
# Loss value: 0.4593992841
# Current parameters: [ 0.17   3.142  1.1    1.839 -3.109] (sum to 3.14)
#
# Iter 7 done!
# Loss value: 0.2945992729
# Current parameters: [-0.195  3.142  1.896  1.381 -3.082] (sum to 3.14)
#
# Iter 8 done!
# Loss value: 0.2329317169
# Current parameters: [-0.063  3.142  1.586  1.576 -3.099] (sum to 3.14)
#
# Iter 9 done!
# Loss value: 0.7946117881000001
# Current parameters: [ 0.865  3.095 -0.556  2.878 -3.142] (sum to 3.14)
#
# Iter 10 done!
# Loss value: 0.7637361664000001
# Current parameters: [ 1.027  3.086 -0.972  3.142 -3.142] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.23275800250000003
#             Iterations: 10
#             Function evaluations: 74
#             Gradient evaluations: 10
#
# Total time of optimization: 00:01:11
# Optimization results:
#   optimizer    eps                                       final_params  \
# 0     slsqp  0.100  [0.0035150646932049327, 3.141592653589793, 1.5...
# 1     slsqp  0.010  [0.05129190126358469, 3.089153443633795, 1.564...
# 2     slsqp  0.001  [-0.053379802440739414, 3.1411256398683642, 1....
#
#    final_loss
# 0    0.132642
# 1    0.182056
# 2    0.232758
# Best parameters (sum to 3.14):	[ 0.004  3.142  1.572  1.566 -3.142]
# Best parameters (sum to 1):	[ 0.001  1.     0.5    0.498 -1.   ]
# ################################################################################
# Single trotterization step:
# ################################################################################
#
# All steps + measurements of state tomography:
# ################################################################################
#
# 1/8 - Job ID 560cd1f7-18b2-4050-ae3f-d81c32ad9ea0
# 2/8 - Job ID 6809b877-2995-46e1-8cb9-9c54ac2e04b4
# 3/8 - Job ID 6f267ffd-39b3-4be0-b914-e9c36e744fa9
# 4/8 - Job ID 36204621-d67c-4ec3-bdf3-d0749f922035
# 5/8 - Job ID 261cc170-8eca-435e-b996-f5eeb696b73c
# 6/8 - Job ID 05ac0196-5a73-4728-9500-7a89e8286fc1
# 7/8 - Job ID a2321346-011f-45dd-b6ff-df3f5afdce16
# 8/8 - Job ID b6368f60-9f1e-442f-a050-131e2fe4e854
#
# ################################################################################
#
# Final results - order: 1 - strotter steps: 5
#
# State tomography fidelity = 0.6346 ± 0.0025
#
# ################################################################################
#
# Starting simulation for times from 0 to pi!
# Simulation ended!
# Total time of simulation: 00:01:30

# %%
order, trotter_steps = 1, 7
uniform_times = False
params_bounds_min = -np.pi
backend_opt, backend_state_tomo = sim_noisy_jakarta, sim_noisy_jakarta

optimize_params_and_run(order, trotter_steps, uniform_times, params_bounds_min,
                        backend_opt, backend_state_tomo)
# Out:
# ################################################################################
#
# Starting optimization!
#
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.1
# ==================================================
#
# Iter 1 done!
# Loss value: -0.09199
# Current parameters: [ 0.223  3.142  2.324  1.588 -1.222 -1.005 -1.909] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.14617
# Current parameters: [ 0.378  2.952  2.27   1.694 -1.095 -1.149 -1.908] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.08276
# Current parameters: [ 1.533  1.614  2.199  2.485 -0.836 -1.807 -2.046] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.34966
# Current parameters: [ 0.938  2.429  2.116  2.15  -0.876 -1.384 -2.231] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.27851
# Current parameters: [ 0.54   2.702  2.323  1.954 -0.91  -1.243 -2.224] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.37539
# Current parameters: [ 0.752  2.461  2.278  2.113 -0.878 -1.343 -2.242] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.38845
# Current parameters: [ 0.767  2.435  2.364  2.155 -0.843 -1.412 -2.324] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.16609
# Current parameters: [ 0.804  2.243  3.078  2.676 -0.58  -2.1   -2.979] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.39647
# Current parameters: [ 0.742  2.456  2.423  2.236 -0.841 -1.491 -2.383] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.39802
# Current parameters: [ 0.731  2.457  2.433  2.275 -0.843 -1.523 -2.388] (sum to 3.14)
#
# Iter 11 done!
# Loss value: -0.39937
# Current parameters: [ 0.721  2.441  2.436  2.313 -0.832 -1.551 -2.386] (sum to 3.14)
#
# Iter 12 done!
# Loss value: -0.39853
# Current parameters: [ 0.72   2.436  2.431  2.318 -0.823 -1.566 -2.375] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.39937
#             Iterations: 12
#             Function evaluations: 110
#             Gradient evaluations: 12
#
# Total time of optimization: 00:05:54
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.01
# ==================================================
#
# Iter 1 done!
# Loss value: -0.09344
# Current parameters: [ 0.186  3.142  2.371  1.585 -1.202 -1.094 -1.845] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.10698
# Current parameters: [ 0.134  3.142  2.314  1.675 -1.108 -1.134 -1.881] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.12954
# Current parameters: [ 0.043  3.142  2.337  1.829 -1.079 -1.23  -1.901] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.08283
# Current parameters: [-0.868  3.142  2.706  3.142 -0.989 -1.981 -2.01 ] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.2256
# Current parameters: [-0.298  3.142  2.642  2.244 -1.022 -1.595 -1.97 ] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.25931
# Current parameters: [-0.342  3.142  2.685  2.007 -1.009 -1.492 -1.85 ] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.24977
# Current parameters: [-0.196  3.142  2.527  1.705 -1.13  -1.2   -1.707] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.29281
# Current parameters: [-0.317  3.142  2.648  1.946 -1.137 -1.343 -1.797] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.1754
# Current parameters: [-0.291  3.142  2.784  1.884 -1.542 -0.965 -1.869] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.31081
# Current parameters: [-0.292  3.142  2.692  1.914 -1.34  -1.172 -1.802] (sum to 3.14)
#
# Iter 11 done!
# Loss value: -0.31533
# Current parameters: [-0.298  3.142  2.682  1.936 -1.297 -1.224 -1.799] (sum to 3.14)
#
# Iter 12 done!
# Loss value: -0.31541
# Current parameters: [-0.291  3.142  2.681  1.927 -1.309 -1.222 -1.786] (sum to 3.14)
#
# Iter 13 done!
# Loss value: -0.31568
# Current parameters: [-0.282  3.142  2.679  1.909 -1.315 -1.225 -1.767] (sum to 3.14)
#
# Iter 14 done!
# Loss value: -0.24958
# Current parameters: [-0.013  3.142  2.663  1.433 -1.508 -1.368 -1.207] (sum to 3.14)
#
# Iter 15 done!
# Loss value: -0.07066
# Current parameters: [ 2.062  3.142  2.565 -2.282 -2.958 -2.529  3.142] (sum to 3.14)
#
# Iter 16 done!
# Loss value: -0.07803
# Current parameters: [ 2.048  3.142  2.588 -2.292 -2.939 -2.546  3.142] (sum to 3.14)
#
# Iter 17 done!
# Loss value: -0.3252
# Current parameters: [-0.098  3.142  2.706  1.534 -1.412 -1.387 -1.342] (sum to 3.14)
#
# Iter 18 done!
# Loss value: -0.34647
# Current parameters: [-0.161  3.142  2.78   1.537 -1.336 -1.439 -1.381] (sum to 3.14)
#
# Iter 19 done!
# Loss value: -0.36162
# Current parameters: [-0.165  3.142  2.803  1.602 -1.331 -1.46  -1.449] (sum to 3.14)
#
# Iter 20 done!
# Loss value: -0.22064
# Current parameters: [-0.091  3.142  3.142  2.088 -1.416 -1.807 -1.916] (sum to 3.14)
#
# Iter 21 done!
# Loss value: -0.42795
# Current parameters: [-0.087  3.142  3.018  1.798 -1.438 -1.659 -1.632] (sum to 3.14)
#
# Iter 22 done!
# Loss value: -0.4597
# Current parameters: [-0.048  3.142  3.085  1.712 -1.533 -1.666 -1.55 ] (sum to 3.14)
#
# Iter 23 done!
# Loss value: -0.46506
# Current parameters: [-0.032  3.142  3.094  1.668 -1.577 -1.634 -1.52 ] (sum to 3.14)
#
# Iter 24 done!
# Loss value: -0.46677
# Current parameters: [-0.008  3.142  3.122  1.637 -1.601 -1.634 -1.516] (sum to 3.14)
#
# Iter 25 done!
# Loss value: -0.46739
# Current parameters: [-0.004  3.142  3.125  1.622 -1.602 -1.622 -1.518] (sum to 3.14)
#
# Iter 26 done!
# Loss value: -0.51549
# Current parameters: [ 0.011  3.142  3.142  1.516 -1.571 -1.542 -1.557] (sum to 3.14)
#
# Iter 27 done!
# Loss value: -0.4267
# Current parameters: [ 0.014  3.142  3.142  1.543 -1.571 -1.559 -1.568] (sum to 3.14)
#
# Iter 28 done!
# Loss value: -0.51564
# Current parameters: [ 0.024  3.142  3.142  1.6   -1.608 -1.585 -1.572] (sum to 3.14)
#
# Iter 29 done!
# Loss value: -0.42679
# Current parameters: [ 0.012  3.142  3.142  1.565 -1.589 -1.565 -1.565] (sum to 3.14)
#
# Iter 30 done!
# Loss value: -0.5166
# Current parameters: [-0.009  3.142  3.142  1.588 -1.587 -1.569 -1.565] (sum to 3.14)
#
# Iter 31 done!
# Loss value: -0.5166
# Current parameters: [-2.753e-04  3.142e+00  3.142e+00  1.577e+00 -1.586e+00 -1.567e+00
#  -1.564e+00] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.5166
#             Iterations: 31
#             Function evaluations: 283
#             Gradient evaluations: 31
#
# Total time of optimization: 00:14:02
#
# ==================================================
# Optimizer: SLSQP
# eps = 0.001
# ==================================================
#
# Iter 1 done!
# Loss value: -0.09041
# Current parameters: [ 0.175  3.142  2.371  1.573 -1.218 -1.068 -1.833] (sum to 3.14)
#
# Iter 2 done!
# Loss value: -0.10709
# Current parameters: [ 0.097  3.142  2.322  1.644 -1.118 -1.104 -1.842] (sum to 3.14)
#
# Iter 3 done!
# Loss value: -0.13705
# Current parameters: [-0.006  3.142  2.383  1.72  -1.069 -1.181 -1.847] (sum to 3.14)
#
# Iter 4 done!
# Loss value: -0.05715
# Current parameters: [-1.64   3.142  3.142  2.785 -0.613 -1.961 -1.712] (sum to 3.14)
#
# Iter 5 done!
# Loss value: -0.25743
# Current parameters: [-0.337  3.142  2.664  1.931 -0.985 -1.397 -1.876] (sum to 3.14)
#
# Iter 6 done!
# Loss value: -0.22458
# Current parameters: [-0.04   3.142  2.53   1.903 -1.256 -1.248 -1.89 ] (sum to 3.14)
#
# Iter 7 done!
# Loss value: -0.28969
# Current parameters: [-0.195  3.142  2.668  2.033 -1.289 -1.38  -1.837] (sum to 3.14)
#
# Iter 8 done!
# Loss value: -0.30895
# Current parameters: [-0.212  3.142  2.697  1.927 -1.277 -1.305 -1.829] (sum to 3.14)
#
# Iter 9 done!
# Loss value: -0.31458
# Current parameters: [-0.268  3.142  2.713  1.91  -1.271 -1.286 -1.798] (sum to 3.14)
#
# Iter 10 done!
# Loss value: -0.31878
# Current parameters: [-0.262  3.142  2.703  1.867 -1.32  -1.266 -1.723] (sum to 3.14)
#
# Iter 11 done!
# Loss value: -0.27258
# Current parameters: [-0.143  3.142  2.737  1.593 -1.714 -1.167 -1.307] (sum to 3.14)
#
# Iter 12 done!
# Loss value: -0.33069
# Current parameters: [-0.203  3.142  2.718  1.736 -1.468 -1.276 -1.507] (sum to 3.14)
#
# Iter 13 done!
# Loss value: -0.07224
# Current parameters: [ 0.056  3.142  2.794  1.277 -1.864 -1.595 -0.667] (sum to 3.14)
#
# Iter 14 done!
# Loss value: -0.35142
# Current parameters: [-0.154  3.142  2.77   1.668 -1.524 -1.406 -1.354] (sum to 3.14)
#
# Iter 15 done!
# Loss value: -0.34687
# Current parameters: [-0.143  3.142  2.806  1.703 -1.461 -1.475 -1.43 ] (sum to 3.14)
#
# Iter 16 done!
# Loss value: -0.1935
# Current parameters: [ 0.112  3.142  3.142  2.027 -1.077 -2.09  -2.114] (sum to 3.14)
#
# Iter 17 done!
# Loss value: -0.42401
# Current parameters: [-0.064  3.142  2.946  1.715 -1.379 -1.671 -1.547] (sum to 3.14)
# Iter 18 done!
# Loss value: -0.4454
# Current parameters: [-0.046  3.142  3.066  1.615 -1.383 -1.725 -1.525] (sum to 3.14)
#
# Iter 19 done!
# Loss value: -0.41808
# Current parameters: [-0.045  3.142  3.104  1.58  -1.417 -1.669 -1.553] (sum to 3.14)
#
# Iter 20 done!
# Loss value: -0.45237
# Current parameters: [-0.084  3.142  3.054  1.576 -1.494 -1.555 -1.497] (sum to 3.14)
#
# Iter 21 done!
# Loss value: -0.42059
# Current parameters: [-0.054  3.142  3.099  1.565 -1.495 -1.612 -1.503] (sum to 3.14)
#
# Iter 22 done!
# Loss value: -0.45828
# Current parameters: [-0.045  3.142  3.051  1.648 -1.447 -1.64  -1.567] (sum to 3.14)
#
# Iter 23 done!
# Loss value: -0.4606
# Current parameters: [-0.056  3.142  3.052  1.631 -1.481 -1.594 -1.552] (sum to 3.14)
#
# Iter 24 done!
# Loss value: -0.46131
# Current parameters: [-0.055  3.142  3.05   1.643 -1.53  -1.544 -1.564] (sum to 3.14)
#
# Iter 25 done!
# Loss value: -0.46209
# Current parameters: [-0.051  3.142  3.051  1.653 -1.532 -1.548 -1.574] (sum to 3.14)
#
# Iter 26 done!
# Loss value: -0.41939
# Current parameters: [-0.007  3.142  3.039  1.711 -1.537 -1.577 -1.628] (sum to 3.14)
#
# Iter 27 done!
# Loss value: -0.16688
# Current parameters: [ 0.384  3.142  2.949  2.26  -1.568 -1.915 -2.111] (sum to 3.14)
#
# Iter 28 done!
# Loss value: -0.46298
# Current parameters: [-0.034  3.142  3.047  1.674 -1.541 -1.552 -1.593] (sum to 3.14)
#
# Iter 29 done!
# Loss value: -0.42178
# Current parameters: [-0.031  3.142  3.048  1.672 -1.551 -1.542 -1.596] (sum to 3.14)
#
# Iter 30 done!
# Loss value: -0.45553
# Current parameters: [-0.01   3.142  3.069  1.622 -1.675 -1.402 -1.604] (sum to 3.14)
#
# Iter 31 done!
# Loss value: -0.46384
# Current parameters: [-0.023  3.142  3.056  1.655 -1.59  -1.501 -1.598] (sum to 3.14)
#
# Iter 32 done!
# Loss value: -0.46439
# Current parameters: [-0.018  3.142  3.06   1.65  -1.594 -1.499 -1.599] (sum to 3.14)
#
# Iter 33 done!
# Loss value: -0.46498
# Current parameters: [-0.017  3.142  3.06   1.652 -1.58  -1.517 -1.598] (sum to 3.14)
#
# Iter 34 done!
# Loss value: -0.04089
# Current parameters: [ 0.07   3.142  3.05   1.695 -0.817 -2.469 -1.529] (sum to 3.14)
#
# Iter 35 done!
# Loss value: -0.46583
# Current parameters: [-0.01   3.142  3.061  1.653 -1.541 -1.568 -1.595] (sum to 3.14)
#
# Iter 36 done!
# Loss value: -0.42512
# Current parameters: [ 0.013  3.142  3.076  1.637 -1.537 -1.597 -1.593] (sum to 3.14)
#
# Iter 37 done!
# Loss value: -0.46631
# Current parameters: [-0.003  3.142  3.065  1.653 -1.545 -1.576 -1.594] (sum to 3.14)
#
# Iter 38 done!
# Loss value: -0.45645
# Current parameters: [ 0.094  3.142  3.096  1.659 -1.594 -1.693 -1.561] (sum to 3.14)
#
# Iter 39 done!
# Loss value: -0.42496
# Current parameters: [ 0.016  3.142  3.07   1.654 -1.559 -1.595 -1.587] (sum to 3.14)
#
# Iter 40 done!
# Loss value: -0.46669
# Current parameters: [ 0.015  3.142  3.07   1.652 -1.554 -1.596 -1.587] (sum to 3.14)
#
# Iter 41 done!
# Loss value: -0.46209
# Current parameters: [-0.037  3.142  3.05   1.622 -1.525 -1.511 -1.6  ] (sum to 3.14)
#
# Iter 42 done!
# Loss value: -0.42509
# Current parameters: [ 0.012  3.142  3.068  1.648 -1.554 -1.587 -1.587] (sum to 3.14)
#
# Iter 43 done!
# Loss value: -0.42345
# Current parameters: [ 0.062  3.142  3.081  1.641 -1.616 -1.603 -1.566] (sum to 3.14)
#
# Iter 44 done!
# Loss value: -0.46698
# Current parameters: [ 0.015  3.142  3.069  1.647 -1.56  -1.586 -1.585] (sum to 3.14)
#
# Iter 45 done!
# Loss value: -0.46693
# Current parameters: [ 0.055  3.142  3.073  1.625 -1.623 -1.57  -1.559] (sum to 3.14)
#
# Iter 46 done!
# Loss value: -0.46748
# Current parameters: [ 0.041  3.142  3.07   1.63  -1.602 -1.573 -1.567] (sum to 3.14)
#
# Iter 47 done!
# Loss value: -0.46755
# Current parameters: [ 0.033  3.142  3.069  1.634 -1.589 -1.576 -1.572] (sum to 3.14)
#
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: -0.46755
#             Iterations: 47
#             Function evaluations: 413
#             Gradient evaluations: 47
#
# Total time of optimization: 00:20:32
# Optimization results:
#   optimizer    eps                                       final_params  \
# 1     slsqp  0.010  [-0.008653221672751198, 3.141592653589793, 3.1...
# 2     slsqp  0.001  [0.03694015788769706, 3.1415926535897816, 3.07...
# 0     slsqp  0.100  [0.7212510518156149, 2.4405211293881814, 2.435...
#
#    final_loss
# 1    -0.51660
# 2    -0.46755
# 0    -0.39937
# Best parameters (sum to 3.14):	[-0.009  3.142  3.142  1.588 -1.587 -1.569 -1.565]
# Best parameters (sum to 1):	[-0.003  1.     1.     0.506 -0.505 -0.499 -0.498]
# ################################################################################
# Single trotterization step:
# ################################################################################
#
# All steps + measurements of state tomography:
# ################################################################################
#
# 1/8 - Job ID 085bc0f6-7b04-48d0-8799-adc5e9717900
# 2/8 - Job ID 8d2f58ad-2080-4668-93af-44786f5e7a5b
# 3/8 - Job ID f2b9e1ad-3c7c-437c-816b-019ca15cec68
# 4/8 - Job ID b5024bb6-bd69-4de7-b2e9-57ae2c48c0fe
# 5/8 - Job ID ceee99a4-f7a3-4337-a60b-1828b163870e
# 6/8 - Job ID 927b17aa-5a45-4064-84e5-678409d4ab05
# 7/8 - Job ID e5473fa4-3bf5-46f6-b842-dbfbe347a369
# 8/8 - Job ID 27490d68-1620-43ad-8c89-a16cddc18211
#
# ################################################################################
#
# Final results - order: 1 - strotter steps: 7
#
# State tomography fidelity = 0.5162 ± 0.0029
#
# ################################################################################
#
# Starting simulation for times from 0 to pi!
# Simulation ended!
# Total time of simulation: 00:02:12
